# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')

# %%
# Find the url for 10 pages
base_url="https://www.imdb.com/search/title/?title_type=feature\
&release_date=1930-01-01,2020-12-31\
&countries=us&keywords=based+on+novel\
&languages=en&count=100"

url_list=[base_url]
for i in range(101,2001,100):
    url = base_url+ "&start=" + str(i) + "&ref_=adv_nxt"
    url_list.append(url)

# %%
len(url_list)
# Out:
# 20

# %%
# Create soup_list (13 soup for 13 pages)
def get_soup(url):
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page, "lxml")
    return soup

# %%
soup_list=[]
for url in url_list:
    soup_list.append(get_soup(url))

# %%
len(soup_list)
# Out:
# 20

# %%
# Create movie_div_list (2000 movies, 100 movies a page)
# sort by popularity
movie_div_list=[]
for soup in soup_list:
    for movie in soup.find_all('div',class_="lister-item-content"):
        movie_div_list.append(movie)

# %%
len(movie_div_list)
# Out:
# 2000

# %%
# Create movie_url_list (individual webpage for each movie)

movie_url_list=[]
movie_base_url = "https://www.imdb.com/"

for soup in soup_list:
    divs= [div for div in soup.find_all('div', class_="lister-item-content")]

    for i in range(100):
        movie_url = divs[i].find('a').get('href')
        movie_url_list.append(movie_base_url + movie_url)

# %%
len(movie_url_list)
# Out:
# 2000

# %%
# Create soup_list for the movies

movie_soup_list=[]
for movie_url in movie_url_list[:100]:
    movie_soup = get_soup(movie_url)
    movie_soup_list.append(movie_soup)

# %%
len(movie_soup_list)
# Out:
# 100

# %%
for movie_url in movie_url_list[100:200]:
    movie_soup = get_soup(movie_url)
    movie_soup_list.append(movie_soup)

# %%
len(movie_soup_list)
# Out:
# 200

# %%
for movie_url in movie_url_list[200:500]:
    movie_soup = get_soup(movie_url)
    movie_soup_list.append(movie_soup)

# %%
len(movie_soup_list)
# Out:
# 500

# %%
for movie_url in movie_url_list[500:800]:
    movie_soup = get_soup(movie_url)
    movie_soup_list.append(movie_soup)

# %%
len(movie_soup_list)
# Out:
# 800

# %%
for movie_url in movie_url_list[800:]:
    movie_soup = get_soup(movie_url)
    movie_soup_list.append(movie_soup)

# %%
len(movie_soup_list)
# Out:
# 2000

# %%
# get detailed data from individual movie webpage

def get_movie_detail(soup):
    """
    Getting detailed data from individual movie webpage
    """
    
    headers=['movie_title', 'rating', 'vote', 'certificate', 'genre', 'release_date', 'metascore', 'keywords','budget',\
            'opening_weekend_usa','gross_usa','gross_world','runtime','director','link_d','writer','link_w',\
             'star','link_s','distributor','language','country']
    
    # find movie title
    title = " ".join(soup.find('h1').text.split()[:-1]) ## problem?
    
    # find rating
    rating = float(soup.find('span',attrs={'itemprop':'ratingValue'}).text)
    
    # find vote (rating count)
    vote = int(soup.find('span',attrs={'itemprop':'ratingCount'}).text.replace(',',''))
    
    # find content rating
    certificate = soup.find('div', class_="subtext").text.split()[0]
    
    # find list of genre
    genre_list=[]
    for genres in soup.find('div', class_="subtext").find_all('a')[:-1]:
        genre_list.append(genres.text)
        
    # find release date
    date_pre = soup.find('div', class_="subtext").find_all('a')[-1].text.split('(')[0]
    date = pd.to_datetime(date_pre) ## why is it Timestamp? format ='%d-%B-%Y'
    
    # find metascorre
    if soup.find('div',class_="metacriticScore score_favorable titleReviewBarSubItem") is not None:
        meta = int(soup.find('div',class_="metacriticScore score_favorable titleReviewBarSubItem").text.strip('\n'))
    else:
        meta = np.nan
        
        
    # find plot keywords
    keyword_list=[]
    for keywords in soup.find('div', class_="article", id="titleStoryLine").\
    find('div', class_="see-more inline canwrap").find_all('a')[:-1]:
        keyword_list.append(keywords.text.strip(' '))
        
    
    
    # find budget, opening weekend USA, gross USA, cumulative worldwide gross
    # assign default value:
    budget, opening, gross_usa, gross_cw, distributor = np.nan, np.nan, np.nan, np.nan, np.nan
    for line in soup.find('div', class_="article", id="titleDetails").find_all('h4'):        
        if "Budget:" in line:
            budget = int(''.join(s for s in line.next_sibling if s.isdigit()))
        if "Opening Weekend USA:" in line:
            opening = int(''.join(s for s in line.next_sibling if s.isdigit()))
        if "Gross USA:" in line:
            gross_usa = int(''.join(s for s in line.next_sibling if s.isdigit()))
        if "Cumulative Worldwide Gross:" in line:
            gross_cw = int(''.join(s for s in line.next_sibling if s.isdigit()))
        if "Production Co:" in line:
            distributor = line.findNext().text.replace(' ','')

#     # find runtime
#     if soup.find('div', class_="title_wrapper").find('time') is not None:
#         rt = soup.find('div', class_="title_wrapper").find('time').text.replace('\n','').split()
#         hr = "".join(filter(str.isdigit, rt[0]))
#         if len(rt) > 2:
#             min = "".join(filter(str.isdigit, rt[1]))
#         else:
#             min = "0"
#         runtime = int(hr)*60 + int(min)
#     else:
#         runtime = np.nan
        
    # find runtime
    runtime = np.nan
    try:
        runtime = int(soup.find_all('time')[-1].text.strip(' min'))
    except:
        pass
        
        
        
        
    # find director
    director= np.nan
    director = soup.find('div',class_="credit_summary_item").find('a').text
    link_d = soup.find('div',class_="credit_summary_item").find('a').get('href')
    
    # find writer
    writer = np.nan
    writer_line = soup.find_all('div',class_="credit_summary_item")[1].find_all('a')
    link_w = [w.get('href') for w in writer_line]
    writer = [w.text for w in writer_line]
    if '1 more credit' in writer:
        writer.remove('1 more credit')
        link_w.pop()
        
    # find star
    star = np.nan
    star_line = soup.find_all('div',class_="credit_summary_item")[2].find_all('a')
    link_s = [s.get('href') for s in star_line]
    star = [s.text for s in star_line]
    if 'See full cast & crew' in star:
        star.remove('See full cast & crew')
        link_s.pop()
    
    
    
    # find language
    language= np.nan
    t= []
    matching = []
    for div in soup.find('div', class_="article", id="titleDetails").find_all('div'):
        t.append(div.text.replace('\n','').replace(' ',''))
    
    matching = [s for s in t if 'Language:' in s]
    language = matching[0].replace(':',' ').replace('|',' ').split(' ')[1:]
    
    
    # find country
    country= np.nan
    t= []
    matching = []
    for div in soup.find('div', class_="article", id="titleDetails").find_all('div'):
        t.append(div.text.replace('\n','').replace(' ',''))
    
    matching = [s for s in t if 'Country:' in s]
    country = matching[0].replace(':',' ').replace('|',' ').split(' ')[1:]
    
        
    movie_dict = dict(zip(headers, [title,
                                    rating,
                                    vote,
                                   certificate,
                                   genre_list,
                                   date,
                                   meta,
                                   keyword_list,
                                   budget,
                                   opening,
                                   gross_usa,
                                   gross_cw,
                                   runtime,
                                   director,
                                    link_d,
                                    writer,
                                    link_w,
                                    star,
                                    link_s,
                                   distributor,
                                   language,
                                   country]))
    
    return movie_dict

# %%
# Create list of movie_dict
movie_detail_data=[]
for movie_soup in movie_soup_list:
    movie = get_movie_detail(movie_soup)
    movie_detail_data.append(movie)

# %%
len(movie_detail_data)
# Out:
# 2000

# %%
# Create pd DataFrame of 2000 movies!
movie_df = pd.DataFrame(movie_detail_data)
movie_df.sort_values('gross_world',ascending=False).head(10)
# Out:
#                                        movie_title  rating     vote  \
# 19    Harry Potter and the Deathly Hallows: Part 2     8.1   761802
# 18   The Lord of the Rings: The Return of the King     8.9  1638112
# 184    Pirates of the Caribbean: On Stranger Tides     6.6   480218
# 53                                   Jurassic Park     8.1   865330
# 202                            Alice in Wonderland     6.4   383347
# 28               The Hobbit: An Unexpected Journey     7.8   755808
# 2            Harry Potter and the Sorcerer's Stone     7.6   654936
# 41    Harry Potter and the Deathly Hallows: Part 1     7.7   477337
# 176                                The Jungle Book     7.4   258648
# 75                  Jumanji: Welcome to the Jungle     6.9   318504
#
#     certificate                         genre release_date  metascore  \
# 19        PG-13   [Adventure, Drama, Fantasy]   2011-07-15       85.0
# 18        PG-13    [Action, Adventure, Drama]   2003-12-17       94.0
# 184       PG-13  [Action, Adventure, Fantasy]   2011-05-20        NaN
# 53        PG-13   [Action, Adventure, Sci-Fi]   1993-06-11       68.0
# 202          PG  [Adventure, Family, Fantasy]   2010-03-05        NaN
# 28        PG-13          [Adventure, Fantasy]   2012-12-14        NaN
# 2            PG  [Adventure, Family, Fantasy]   2001-11-16       64.0
# 41        PG-13  [Adventure, Family, Fantasy]   2010-11-19       65.0
# 176          PG    [Adventure, Drama, Family]   2016-04-15       77.0
# 75        PG-13   [Action, Adventure, Comedy]   2017-12-20        NaN
#
#                                               keywords       budget  \
# 19   [ginny weasley character, lucius malfoy charac...  125000000.0
# 18                   [epic, orc, hobbit, ring, battle]   94000000.0
# 184    [pirate, captain, blackbeard, soldier, revenge]  250000000.0
# 53   [dinosaur, tyrannosaurus rex, sneeze, severed ...   63000000.0
# 202  [alice in wonderland, alice character, shrinki...  200000000.0
# 28                [wizard, hobbit, dragon, dwarf, orc]  180000000.0
# 2    [magic, wizard, school of magic, based on nove...  125000000.0
# 41   [based on young adult novel, harry potter movi...  150000000.0
# 176         [jungle, wolf, fire, tiger, black panther]  175000000.0
# 75   [woman with a bare midriff, tattooed trash, ba...   90000000.0
#
#      opening_weekend_usa  ...  runtime          director            link_d  \
# 19           169189427.0  ...    130.0       David Yates  /name/nm0946734/
# 18            72629713.0  ...    192.0     Peter Jackson  /name/nm0001392/
# 184           90151958.0  ...    137.0      Rob Marshall  /name/nm0551128/
# 53            47026828.0  ...    127.0  Steven Spielberg  /name/nm0000229/
# 202          116101023.0  ...    108.0        Tim Burton  /name/nm0000318/
# 28            84617303.0  ...    182.0     Peter Jackson  /name/nm0001392/
# 2             90294621.0  ...    159.0    Chris Columbus  /name/nm0001060/
# 41           125017372.0  ...    146.0       David Yates  /name/nm0946734/
# 176          103261464.0  ...    106.0       Jon Favreau  /name/nm0269463/
# 75            36169328.0  ...    119.0       Jake Kasdan  /name/nm0440458/
#
#                                             writer  \
# 19                    [Steve Kloves, J.K. Rowling]
# 18    [J.R.R. Tolkien, Fran Walsh, 2 more credits]
# 184    [Ted Elliott, Terry Rossio, 7 more credits]
# 53            [Michael Crichton, Michael Crichton]
# 202              [Linda Woolverton, Lewis Carroll]
# 28   [Fran Walsh, Philippa Boyens, 3 more credits]
# 2                     [J.K. Rowling, Steve Kloves]
# 41                    [Steve Kloves, J.K. Rowling]
# 176                [Justin Marks, Rudyard Kipling]
# 75   [Chris McKenna, Erik Sommers, 9 more credits]
#
#                                                 link_w  \
# 19                [/name/nm0460141/, /name/nm0746830/]
# 18   [/name/nm0866058/, /name/nm0909638/, fullcredi...
# 184  [/name/nm0254645/, /name/nm0744429/, fullcredi...
# 53                [/name/nm0000341/, /name/nm0000341/]
# 202               [/name/nm0941314/, /name/nm0140902/]
# 28   [/name/nm0909638/, /name/nm0101991/, fullcredi...
# 2                 [/name/nm0746830/, /name/nm0460141/]
# 41                [/name/nm0460141/, /name/nm0746830/]
# 176               [/name/nm1098479/, /name/nm0456017/]
# 75   [/name/nm0571344/, /name/nm1273099/, fullcredi...
#
#                                                   star  \
# 19       [Daniel Radcliffe, Emma Watson, Rupert Grint]
# 18        [Elijah Wood, Viggo Mortensen, Ian McKellen]
# 184          [Johnny Depp, Penélope Cruz, Ian McShane]
# 53              [Sam Neill, Laura Dern, Jeff Goldblum]
# 202  [Mia Wasikowska, Johnny Depp, Helena Bonham Ca...
# 28    [Martin Freeman, Ian McKellen, Richard Armitage]
# 2     [Daniel Radcliffe, Rupert Grint, Richard Harris]
# 41       [Daniel Radcliffe, Emma Watson, Rupert Grint]
# 176            [Neel Sethi, Bill Murray, Ben Kingsley]
# 75          [Dwayne Johnson, Karen Gillan, Kevin Hart]
#
#                                                 link_s  \
# 19   [/name/nm0705356/, /name/nm0914612/, /name/nm0...
# 18   [/name/nm0000704/, /name/nm0001557/, /name/nm0...
# 184  [/name/nm0000136/, /name/nm0004851/, /name/nm0...
# 53   [/name/nm0000554/, /name/nm0000368/, /name/nm0...
# 202  [/name/nm1985859/, /name/nm0000136/, /name/nm0...
# 28   [/name/nm0293509/, /name/nm0005212/, /name/nm0...
# 2    [/name/nm0705356/, /name/nm0342488/, /name/nm0...
# 41   [/name/nm0705356/, /name/nm0914612/, /name/nm0...
# 176  [/name/nm5888481/, /name/nm0000195/, /name/nm0...
# 75   [/name/nm0425005/, /name/nm2394794/, /name/nm0...
#
#                   distributor                                 language  \
# 19                WarnerBros.                                [English]
# 18              NewLineCinema  [English, Quenya, OldEnglish, Sindarin]
# 184        WaltDisneyPictures                       [English, Spanish]
# 53          UniversalPictures                       [English, Spanish]
# 202        WaltDisneyPictures                                [English]
# 28   Metro-Goldwyn-Mayer(MGM)                                [English]
# 2                 WarnerBros.                                [English]
# 41                WarnerBros.                                [English]
# 176     FairviewEntertainment                                [English]
# 75           ColumbiaPictures                                [English]
#
#                                           country
# 19                                      [UK, USA]
# 18                              [NewZealand, USA]
# 184                                     [USA, UK]
# 53                                          [USA]
# 202                                     [USA, UK]
# 28                              [NewZealand, USA]
# 2                                       [UK, USA]
# 41                                      [UK, USA]
# 176                                     [UK, USA]
# 75   [USA, India, Canada, UK, Australia, Germany]
#
# [10 rows x 22 columns]

# %%
# Save the data to pickle file
movie_df.to_pickle('../dump/movie_data')

# %% [markdown]
# ### Simple data visualization

# %%
# Test loading data from dump
movie_df = pd.read_pickle('../dump/movie_data')

# %%
movie_df
# Out:
#                                             movie_title  rating     vote  \
# 0                                     After We Collided     5.0    16457
# 1                                         The Godfather     9.2  1614204
# 2                 Harry Potter and the Sorcerer's Stone     7.6   654936
# 3                                               Unknown     6.8   248673
# 4     The Lord of the Rings: The Fellowship of the Ring     8.8  1656253
# ...                                                 ...     ...      ...
# 1995                                   From the Terrace     6.7     2437
# 1996                                    V.I. Warshawski     5.0     4713
# 1997                               Anne of Green Gables     7.0     1114
# 1998                              Odds Against Tomorrow     7.4     3781
# 1999                                 Once Is Not Enough     4.6      630
#
#      certificate                         genre release_date  metascore  \
# 0              R              [Drama, Romance]   2020-10-23        NaN
# 1              R                [Crime, Drama]   1972-03-24      100.0
# 2             PG  [Adventure, Family, Fantasy]   2001-11-16       64.0
# 3          PG-13            [Action, Thriller]   2011-02-18        NaN
# 4          PG-13    [Action, Adventure, Drama]   2001-12-19       92.0
# ...          ...                           ...          ...        ...
# 1995      Passed              [Drama, Romance]   1960-09-09        NaN
# 1996           R       [Action, Comedy, Crime]   1991-07-26        NaN
# 1997      Passed       [Comedy, Drama, Family]   1934-11-23        NaN
# 1998    Approved      [Crime, Drama, Thriller]   1959-11-01        NaN
# 1999           R              [Drama, Romance]   1975-06-20        NaN
#
#                                                keywords       budget  \
# 0     [sequel, birthday, boyfriend girlfriend sex, b...          NaN
# 1     [crime family, mafia, patriarch, organized cri...    6000000.0
# 2     [magic, wizard, school of magic, based on nove...  125000000.0
# 3            [amnesia, coma, airport, scientist, nurse]   30000000.0
# 4                      [ring, quest, hobbit, epic, elf]   93000000.0
# ...                                                 ...          ...
# 1995  [mother son relationship, wilmington delaware,...          NaN
# 1996  [female stockinged feet, pantyhose, camera sho...          NaN
# 1997  [character name as title, anne of green gables...     226000.0
# 1998  [new york city, heist, bank robbery, caper, ne...          NaN
# 1999  [older man younger woman relationship, age dif...          NaN
#
#       opening_weekend_usa  ...  runtime              director  \
# 0                422899.0  ...    105.0          Roger Kumble
# 1                302393.0  ...    175.0  Francis Ford Coppola
# 2              90294621.0  ...    159.0        Chris Columbus
# 3              21856389.0  ...    113.0    Jaume Collet-Serra
# 4              47211490.0  ...    171.0         Peter Jackson
# ...                   ...  ...      ...                   ...
# 1995                  NaN  ...    149.0           Mark Robson
# 1996            3603338.0  ...     89.0            Jeff Kanew
# 1997                  NaN  ...     78.0    George Nichols Jr.
# 1998                  NaN  ...    100.0           Robert Wise
# 1999                  NaN  ...    121.0             Guy Green
#
#                 link_d                                             writer  \
# 0     /name/nm0474955/                          [Anna Todd, Mario Celaya]
# 1     /name/nm0000338/                 [Mario Puzo, Francis Ford Coppola]
# 2     /name/nm0001060/                       [J.K. Rowling, Steve Kloves]
# 3     /name/nm1429471/                 [Oliver Butcher, Stephen Cornwell]
# 4     /name/nm0001392/       [J.R.R. Tolkien, Fran Walsh, 2 more credits]
# ...                ...                                                ...
# 1995  /name/nm0733476/                       [John O'Hara, Ernest Lehman]
# 1996  /name/nm0437596/     [Sara Paretsky, Edward Taylor, 3 more credits]
# 1997  /name/nm0629519/                  [Sam Mintz, Lucy Maud Montgomery]
# 1998  /name/nm0936404/  [William P. McGivern, Abraham Polonsky, 2 more...
# 1999  /name/nm0337885/             [Julius J. Epstein, Jacqueline Susann]
#
#                                                  link_w  \
# 0                  [/name/nm6849771/, /name/nm8800659/]
# 1                  [/name/nm0701374/, /name/nm0000338/]
# 2                  [/name/nm0746830/, /name/nm0460141/]
# 3                  [/name/nm0124700/, /name/nm0180508/]
# 4     [/name/nm0866058/, /name/nm0909638/, fullcredi...
# ...                                                 ...
# 1995               [/name/nm0641274/, /name/nm0499626/]
# 1996  [/name/nm0661386/, /name/nm0852324/, fullcredi...
# 1997               [/name/nm0591791/, /name/nm0599844/]
# 1998  [/name/nm0569423/, /name/nm0689796/, fullcredi...
# 1999               [/name/nm0258493/, /name/nm0839797/]
#
#                                                    star  \
# 0     [Josephine Langford, Hero Fiennes Tiffin, Dyla...
# 1                [Marlon Brando, Al Pacino, James Caan]
# 2      [Daniel Radcliffe, Rupert Grint, Richard Harris]
# 3            [Liam Neeson, Diane Kruger, January Jones]
# 4            [Elijah Wood, Ian McKellen, Orlando Bloom]
# ...                                                 ...
# 1995          [Paul Newman, Joanne Woodward, Myrna Loy]
# 1996  [Kathleen Turner, Jay O. Sanders, Charles Durn...
# 1997             [Anne Shirley, Tom Brown, O.P. Heggie]
# 1998     [Harry Belafonte, Robert Ryan, Gloria Grahame]
# 1999        [Kirk Douglas, Alexis Smith, David Janssen]
#
#                                                  link_s  \
# 0     [/name/nm6466214/, /name/nm2842005/, /name/nm0...
# 1     [/name/nm0000008/, /name/nm0000199/, /name/nm0...
# 2     [/name/nm0705356/, /name/nm0342488/, /name/nm0...
# 3     [/name/nm0000553/, /name/nm1208167/, /name/nm0...
# 4     [/name/nm0000704/, /name/nm0005212/, /name/nm0...
# ...                                                 ...
# 1995  [/name/nm0000056/, /name/nm0940946/, /name/nm0...
# 1996  [/name/nm0000678/, /name/nm0761587/, /name/nm0...
# 1997  [/name/nm0794297/, /name/nm0114805/, /name/nm0...
# 1998  [/name/nm0000896/, /name/nm0752813/, /name/nm0...
# 1999  [/name/nm0000018/, /name/nm0807252/, /name/nm0...
#
#                   distributor                            language  \
# 0                    CalMaple                  [English, Chinese]
# 1           ParamountPictures           [English, Italian, Latin]
# 2                 WarnerBros.                           [English]
# 3     DarkCastleEntertainment  [English, German, Turkish, Arabic]
# 4               NewLineCinema                 [English, Sindarin]
# ...                       ...                                 ...
# 1995                Linebrook                           [English]
# 1996        HollywoodPictures                           [English]
# 1997         RKORadioPictures                           [English]
# 1998        HarBelProductions                           [English]
# 1999         AriesProductions                           [English]
#
#                          country
# 0                          [USA]
# 1                          [USA]
# 2                      [UK, USA]
# 3     [UK, Germany, France, USA]
# 4              [NewZealand, USA]
# ...                          ...
# 1995                       [USA]
# 1996                       [USA]
# 1997                       [USA]
# 1998                       [USA]
# 1999                       [USA]
#
# [2000 rows x 22 columns]

# %%
# Check years
movie_df.release_date.dt.year.nunique(),np.sort(movie_detail_df.release_date.dt.year.unique())
# Out:
# (92,
#  array([1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940,
#         1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951,
#         1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962,
#         1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973,
#         1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984,
#         1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995,
#         1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
#         2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017,
#         2018, 2019, 2020, 2021]))

# %%
movie_df.columns
# Out:
# Index(['movie_title', 'rating', 'vote', 'certificate', 'genre', 'release_date',
#        'metascore', 'keywords', 'budget', 'opening_weekend_usa', 'gross_usa',
#        'gross_world', 'runtime', 'director', 'link_d', 'writer', 'link_w',
#        'star', 'link_s', 'distributor', 'language', 'country'],
#       dtype='object')

# %%
x = movie_df['release_date'].dt.year
y = movie_df['rating']
fig, ax = plt.subplots(1,1)
plt.scatter(x,y,alpha=0.5)
ax.set_title('',fontsize=15)
ax.set_xlabel('Year',fontsize=15)
ax.set_ylabel('Rating',fontsize=15)
ax.set_yticks([3,4,5,6,7,8,9])
ax.set_yticklabels(['3.0','4.0','5.0','6.0','7.0','8.0','9.0'])
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
# Out:
# (array([3, 4, 5, 6, 7, 8, 9]),
#  [Text(0, 3, '3.0'),
#   Text(0, 4, '4.0'),
#   Text(0, 5, '5.0'),
#   Text(0, 6, '6.0'),
#   Text(0, 7, '7.0'),
#   Text(0, 8, '8.0'),
#   Text(0, 9, '9.0')])

# %%
movie_df.dropna(subset=['gross_world'])
x = movie_df['gross_world']
y = movie_df['rating']
fig, ax = plt.subplots(1,1)
plt.scatter(x,y,alpha=0.5)
ax.set_title('',fontsize=15)
ax.set_xlabel('Gross World($)',fontsize=15)
ax.set_ylabel('Rating',fontsize=15)
ax.set_xticks([100e6,200e6,300e6,400e6])
ax.set_xticklabels(['100M','200M','300M','400M'])
ax.set_yticks([3,4,5,6,7,8,9])
ax.set_yticklabels(['3.0','4.0','5.0','6.0','7.0','8.0','9.0'])
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
# Out:
# (array([3, 4, 5, 6, 7, 8, 9]),
#  [Text(0, 3, '3.0'),
#   Text(0, 4, '4.0'),
#   Text(0, 5, '5.0'),
#   Text(0, 6, '6.0'),
#   Text(0, 7, '7.0'),
#   Text(0, 8, '8.0'),
#   Text(0, 9, '9.0')])

# %%
movie_df.dropna(subset=['gross_usa'])
x = movie_df['gross_usa']
y = movie_df['rating']
fig, ax = plt.subplots(1,1)
plt.scatter(x,y,alpha=0.5)
ax.set_title('',fontsize=15)
ax.set_xlabel('Gross USA ($)',fontsize=15)
ax.set_ylabel('Rating',fontsize=15)
ax.set_xticks([100e6,200e6,300e6,400e6])
ax.set_xticklabels(['100M','200M','300M','400M'])
ax.set_yticks([3,4,5,6,7,8,9])
ax.set_yticklabels(['3.0','4.0','5.0','6.0','7.0','8.0','9.0'])
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
# Out:
# (array([3, 4, 5, 6, 7, 8, 9]),
#  [Text(0, 3, '3.0'),
#   Text(0, 4, '4.0'),
#   Text(0, 5, '5.0'),
#   Text(0, 6, '6.0'),
#   Text(0, 7, '7.0'),
#   Text(0, 8, '8.0'),
#   Text(0, 9, '9.0')])

# %%
movie_df.dropna(subset=['vote'])
x = movie_df['vote']
y = movie_df['rating']

fig, ax = plt.subplots(1,1)
plt.scatter(x,y,alpha=0.5)
ax.set_title('',fontsize=15)
ax.set_xlabel('Vote (count)',fontsize=15)
ax.set_ylabel('Rating',fontsize=15)
ax.set_xticks([0,100e3,200e3,300e3,400e3,500e3,600e3,700e3,800e3])
ax.set_xticklabels(['0','100k','200k','300k','400k','500k','600k','700k','800k',])
ax.set_yticks([3,4,5,6,7,8,9])
ax.set_yticklabels(['3.0','4.0','5.0','6.0','7.0','8.0','9.0'])
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
# Out:
# (array([3, 4, 5, 6, 7, 8, 9]),
#  [Text(0, 3, '3.0'),
#   Text(0, 4, '4.0'),
#   Text(0, 5, '5.0'),
#   Text(0, 6, '6.0'),
#   Text(0, 7, '7.0'),
#   Text(0, 8, '8.0'),
#   Text(0, 9, '9.0')])

# %%
movie_df.dropna(subset=['runtime'])
movie_df = movie_df[movie_df.runtime <300]
x = movie_df['runtime']
y = movie_df['rating']

fig, ax = plt.subplots(1,1)
plt.scatter(x,y,alpha=0.5)
ax.set_title('',fontsize=15)
ax.set_xlabel('Runtime (min)',fontsize=15)
ax.set_ylabel('Rating',fontsize=15)

ax.set_xticks([50,100,150,100,250])
ax.set_xticklabels(['50','100','150','200','250'])
ax.set_yticks([3,4,5,6,7,8,9])
ax.set_yticklabels(['3.0','4.0','5.0','6.0','7.0','8.0','9.0'])
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
# Out:
# (array([3, 4, 5, 6, 7, 8, 9]),
#  [Text(0, 3, '3.0'),
#   Text(0, 4, '4.0'),
#   Text(0, 5, '5.0'),
#   Text(0, 6, '6.0'),
#   Text(0, 7, '7.0'),
#   Text(0, 8, '8.0'),
#   Text(0, 9, '9.0')])

# %% [markdown]
# ### Construct director DataFrame

# %%
# Create list of directors from the 2000 movies
movie_temp = movie_df.drop_duplicates(subset=['director'])
director_list = movie_df.director.unique()

# %%
len(director_list)
# Out:
# 1095

# %%
import numpy as np
import pandas as pd
def get_movie_brief(soup):
    """
    Getting brief data from individual movie webpage (for director dictionary)
    """
    
    headers=['director','title','year','rating','vote','genre_list','budget','opening','gross_usa',\
             'gross_cw','runtime','writer','star','distributor']
    
    # find movie title
    title = " ".join(soup.find('h1').text.split()[:-1])
    
    # find rating
    rating = np.nan
    try:
        rating = float(soup.find('span',attrs={'itemprop':'ratingValue'}).text)
    except:
        pass
    
    # find vote (rating count)
    vote = np.nan
    try:
        vote = int(soup.find('span',attrs={'itemprop':'ratingCount'}).text.replace(',',''))
    except:
        pass
    
    
    # find list of genre
    genre_list=[]
    try:
        for genres in soup.find('div', class_="subtext").find_all('a')[:-1]:
            genre_list.append(genres.text)
    except:
        pass
    
        
    # find release date
    date = np.nan
    try:
        date_pre = soup.find('div', class_="subtext").find_all('a')[-1].text.split('(')[0]
        date = pd.to_datetime(date_pre) ## why is it Timestamp? format ='%d-%B-%Y'
    except:
        pass

    
#     # find metascorre
#     if soup.find('div',class_="metacriticScore score_favorable titleReviewBarSubItem") is not None:
#         meta = int(soup.find('div',class_="metacriticScore score_favorable titleReviewBarSubItem").text.strip('\n'))
#     else:
#         meta = np.nan
        
        
#     # find plot keywords
#     keyword_list=[]
#     for keywords in soup.find('div', class_="article", id="titleStoryLine").\
#     find('div', class_="see-more inline canwrap").find_all('a')[:-1]:
#         keyword_list.append(keywords.text.strip(' '))
        
    
    
    # find budget, opening weekend USA, gross USA, cumulative worldwide gross
    # assign default value:
    budget, opening, gross_usa, gross_cw, distributor = np.nan, np.nan, np.nan, np.nan, np.nan
    try:
        for line in soup.find('div', class_="article", id="titleDetails").find_all('h4'):        
            if "Budget:" in line:
                budget = int(''.join(s for s in line.next_sibling if s.isdigit()))
            if "Opening Weekend USA:" in line:
                opening = int(''.join(s for s in line.next_sibling if s.isdigit()))
            if "Gross USA:" in line:
                gross_usa = int(''.join(s for s in line.next_sibling if s.isdigit()))
            if "Cumulative Worldwide Gross:" in line:
                gross_cw = int(''.join(s for s in line.next_sibling if s.isdigit()))
            if "Production Co:" in line:
                distributor = line.findNext().text.replace(' ','')
    except:
        pass

        
    # find runtime
    runtime = np.nan
    try:
        runtime = int(soup.find_all('time')[-1].text.strip(' min'))
    except:
        pass
        
        
        
        
    # find director
    director= np.nan
    try:
        director = soup.find('div',class_="credit_summary_item").find('a').text
        link_d = soup.find('div',class_="credit_summary_item").find('a').get('href')
    except:
        pass
    
    # find writer
    writer = np.nan
    try:
        writer_line = soup.find_all('div',class_="credit_summary_item")[1].find_all('a')
        link_w = [w.get('href') for w in writer_line]
        writer = [w.text for w in writer_line]
        if '1 more credit' in writer:
            writer.remove('1 more credit')
            link_w.pop()
    except:
        pass
    
        
    # find star
    star = np.nan
    try:
        star_line = soup.find_all('div',class_="credit_summary_item")[2].find_all('a')
        link_s = [s.get('href') for s in star_line]
        star = [s.text for s in star_line]
        if 'See full cast & crew' in star:
            star.remove('See full cast & crew')
            link_s.pop()
    except:
        pass
    
    
    
#     # find language
#     language= np.nan
#     t= []
#     matching = []
#     for div in soup.find('div', class_="article", id="titleDetails").find_all('div'):
#         t.append(div.text.replace('\n','').replace(' ',''))
    
#     matching = [s for s in t if 'Language:' in s]
#     language = matching[0].replace(':',' ').replace('|',' ').split(' ')[1:]
    
    
#     # find country
#     country= np.nan
#     t= []
#     matching = []
#     for div in soup.find('div', class_="article", id="titleDetails").find_all('div'):
#         t.append(div.text.replace('\n','').replace(' ',''))
    
#     matching = [s for s in t if 'Country:' in s]
#     country = matching[0].replace(':',' ').replace('|',' ').split(' ')[1:]
    
        
    movie_dict = dict(zip(headers, [director,
                                    title,
                                    date,
                                    rating,
                                    vote,
                                   genre_list,
                                   budget,
                                   opening,
                                   gross_usa,
                                   gross_cw,
                                   runtime,
                                    writer,
                                    star,
                                   distributor]))
    
    return movie_dict

# %%
# Create a dictionary of director: link
director_link_dict = movie_temp[['director','link_d']].set_index('director').T.to_dict('list')

# %%
base_url = "https://www.imdb.com"
director = "Francis Ford Coppola"
director_link = "/name/nm0000338/"
director_url = base_url + director_link
director_soup = get_soup(director_url)
films = director_soup.find('div', id="filmo-head-director").findNext('div')
director_dict = {}
headers = ['director',]

for film in films:
    movie = film.find('a')
    if type(movie) != int:
        movie_title = movie.text
        movie_link = movie.get('href')
        
        movie_soup = get_soup(base_url + movie_link)
        movie_brief = get_movie_brief(movie_soup)
        
director_dict = dict(zip(headers, movie_brief))

# %%
director_film_list=[]
for film in films:
    movie_title = film.find('a').text
    movie_link = film.find('a').get('href')
    movie_soup = get_soup(base_url + movie_link)
    
    detail = get_movie_brief(movie_soup)
    director_film_list.append(detail)
director_film_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-114-4a43a2950f09> in <module>
#       1 director_film_list=[]
# ----> 2 for film in films:
#       3     movie_title = film.find('a').text
#       4     movie_link = film.find('a').get('href')
#       5     movie_soup = get_soup(base_url + movie_link)
#
# NameError: name 'films' is not defined

# %%
# Create list of films from these 1095 directors

director_film_list=[]
base_url = "https://www.imdb.com"
for director in director_link_dict:
    director_url = base_url + director_link_dict[director][0]
    director_soup = get_soup(director_url)
    films = director_soup.find('div', id="filmo-head-director").findNext('div')
    
    for film in films:
        movie = film.find('a')
        if type(movie) != int:
            movie_title = movie.text
            movie_link = movie.get('href')
            movie_soup = get_soup(base_url + movie_link)
    
            detail = get_movie_brief(movie_soup)
            director_film_list.append(detail)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-133-d9da115f58c7> in <module>
#      13             movie_soup = get_soup(base_url + movie_link)
#      14
# ---> 15             detail = get_movie_brief(movie_soup)
#      16             director_film_list.append(detail)
#
# <ipython-input-92-9073245804d5> in get_movie_brief(soup)
#      63     # assign default value:
#      64     budget, opening, gross_usa, gross_cw, distributor = np.nan, np.nan, np.nan, np.nan, np.nan
# ---> 65     for line in soup.find('div', class_="article", id="titleDetails").find_all('h4'):
#      66         if "Budget:" in line:
#      67             budget = int(''.join(s for s in line.next_sibling if s.isdigit()))
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
len(director_film_list)
# Out:
# 1670

# %%
director_link = (movie_temp[['director','link_d']]).reset_index().drop(columns=['index'])

# %%
director_link[director_link.director=="Peter Berg"]
# Out:
#       director            link_d
# 66  Peter Berg  /name/nm0000916/

# %%
director_link.iloc[66:]
# Out:
#                 director            link_d
# 66            Peter Berg  /name/nm0000916/
# 67     Wolfgang Petersen  /name/nm0000583/
# 68            Tom Hooper  /name/nm0393799/
# 69         Thea Sharrock  /name/nm4824763/
# 70          Marc Forster  /name/nm0286975/
# ...                  ...               ...
# 1090          Noel Black  /name/nm0085457/
# 1091        Victor Vicas  /name/nm0895857/
# 1092          Jeff Kanew  /name/nm0437596/
# 1093  George Nichols Jr.  /name/nm0629519/
# 1094           Guy Green  /name/nm0337885/
#
# [1029 rows x 2 columns]

# %%
director_link_dict = director_link.iloc[66:].set_index('director').T.to_dict('list')
director_link_dict
# Out:
# {'Peter Berg': ['/name/nm0000916/'],
#  'Wolfgang Petersen': ['/name/nm0000583/'],
#  'Tom Hooper': ['/name/nm0393799/'],
#  'Thea Sharrock': ['/name/nm4824763/'],
#  'Marc Forster': ['/name/nm0286975/'],
#  'Alfred Hitchcock': ['/name/nm0000033/'],
#  'Andrea Di Stefano': ['/name/nm0224331/'],
#  'Brian De Palma': ['/name/nm0000361/'],
#  'Bill Condon': ['/name/nm0174374/'],
#  'Nick Cassavetes': ['/name/nm0001024/'],
#  'P.J. Hogan': ['/name/nm0389591/'],
#  'Amy Heckerling': ['/name/nm0002132/'],
#  'Tim Burton': ['/name/nm0000318/'],
#  'Andrew Adamson': ['/name/nm0011470/'],
#  'Michael Mann': ['/name/nm0000520/'],
#  'Sharon Maguire': ['/name/nm0536632/'],
#  'Kelly Reichardt': ['/name/nm0716980/'],
#  'Nicolas Winding Refn': ['/name/nm0716347/'],
#  'Taylor Hackford': ['/name/nm0000431/'],
#  'Susanne Bier': ['/name/nm0081540/'],
#  'Adrian Lyne': ['/name/nm0001490/'],
#  'Chris Weitz': ['/name/nm0919363/'],
#  'Danny DeVito': ['/name/nm0000362/'],
#  'Steve McQueen': ['/name/nm2588606/'],
#  'Oliver Stone': ['/name/nm0000231/'],
#  'Clint Eastwood': ['/name/nm0000142/'],
#  'Angelina Jolie': ['/name/nm0001401/'],
#  'Fede Alvarez': ['/name/nm1793079/'],
#  'Doug Liman': ['/name/nm0510731/'],
#  'Wes Ball': ['/name/nm1226871/'],
#  'David Frankel': ['/name/nm0291205/'],
#  'Ron Howard': ['/name/nm0000165/'],
#  'Edward Norton': ['/name/nm0001570/'],
#  'David Lean': ['/name/nm0000180/'],
#  'Curtis Hanson': ['/name/nm0000436/'],
#  'Robert Stevenson': ['/name/nm0829038/'],
#  'Richard Attenborough': ['/name/nm0000277/'],
#  'Björn Runge': ['/name/nm0750275/'],
#  'Lasse Hallström': ['/name/nm0002120/'],
#  'Neil Burger': ['/name/nm1139726/'],
#  'Ben Affleck': ['/name/nm0000255/'],
#  'Michael Noer': ['/name/nm1840064/'],
#  'Nancy Meyers': ['/name/nm0583600/'],
#  'Mike Figgis': ['/name/nm0001214/'],
#  'Renny Harlin': ['/name/nm0001317/'],
#  'Victor Fleming': ['/name/nm0281808/'],
#  'Martin Brest': ['/name/nm0000976/'],
#  'Randal Kleiser': ['/name/nm0459170/'],
#  'Ashley Avis': ['/name/nm2382037/'],
#  'Sydney Pollack': ['/name/nm0001628/'],
#  'Mel Stuart': ['/name/nm0835799/'],
#  'Bernardo Bertolucci': ['/name/nm0000934/'],
#  'Rob Marshall': ['/name/nm0551128/'],
#  'James Foley': ['/name/nm0001226/'],
#  'Stuart Rosenberg': ['/name/nm0742341/'],
#  'Tom Tykwer': ['/name/nm0878756/'],
#  'Kevin Costner': ['/name/nm0000126/'],
#  'Ted Kotcheff': ['/name/nm0467646/'],
#  'James Ponsoldt': ['/name/nm1242054/'],
#  'Duncan Jones': ['/name/nm1512910/'],
#  'William Friedkin': ['/name/nm0001243/'],
#  'Joel Schumacher': ['/name/nm0001708/'],
#  'Jon Favreau': ['/name/nm0269463/'],
#  'John Hillcoat': ['/name/nm0384825/'],
#  'Dean DeBlois': ['/name/nm0213450/'],
#  'Paul Verhoeven': ['/name/nm0000682/'],
#  'Ang Lee': ['/name/nm0000487/'],
#  'Gillian Armstrong': ['/name/nm0000788/'],
#  'Donovan Marsh': ['/name/nm1804518/'],
#  'Nicolas Roeg': ['/name/nm0001676/'],
#  'Edward Zwick': ['/name/nm0001880/'],
#  'Douglas McGrath': ['/name/nm0569790/'],
#  'Alexander Payne': ['/name/nm0668247/'],
#  'Luke Greenfield': ['/name/nm0339004/'],
#  'Gregory Hoblit': ['/name/nm0387706/'],
#  'John Crowley': ['/name/nm1259871/'],
#  'Antoine Fuqua': ['/name/nm0298807/'],
#  'Todd Haynes': ['/name/nm0001331/'],
#  'Sofia Coppola': ['/name/nm0001068/'],
#  'Ken Hughes': ['/name/nm0400731/'],
#  'Danny Boyle': ['/name/nm0000965/'],
#  'Nikolaj Arcel': ['/name/nm1064048/'],
#  'Neil Jordan': ['/name/nm0001403/'],
#  'Brett Ratner': ['/name/nm0711840/'],
#  'Anthony Minghella': ['/name/nm0005237/'],
#  'Tomas Alfredson': ['/name/nm0019247/'],
#  'Sidney Lumet': ['/name/nm0001486/'],
#  'Josh Boone': ['/name/nm1837748/'],
#  'Robert Luketic': ['/name/nm0525659/'],
#  'Andrew Bergman': ['/name/nm0000921/'],
#  'Vince Marcello': ['/name/nm1479803/'],
#  'Wes Anderson': ['/name/nm0027572/'],
#  'David Leitch': ['/name/nm0500610/'],
#  'Stephen Frears': ['/name/nm0001241/'],
#  'Tony Scott': ['/name/nm0001716/'],
#  'Greg Berlanti': ['/name/nm0075528/'],
#  'Paul Greengrass': ['/name/nm0339030/'],
#  'Brad Furman': ['/name/nm1026778/'],
#  'David Slade': ['/name/nm1720541/'],
#  'Quentin Tarantino': ['/name/nm0000233/'],
#  'Garry Marshall': ['/name/nm0005190/'],
#  'Ronald Neame': ['/name/nm0623768/'],
#  'Peter Hewitt': ['/name/nm0382072/'],
#  'Bob Clark': ['/name/nm0163706/'],
#  'Stephen Sommers': ['/name/nm0814085/'],
#  'Brian Duffield': ['/name/nm3929259/'],
#  'Andrew Dominik': ['/name/nm0231596/'],
#  'Reed Morano': ['/name/nm1543747/'],
#  'Lynne Ramsay': ['/name/nm0708903/'],
#  'D.J. Caruso': ['/name/nm0142286/'],
#  'John Boorman': ['/name/nm0000958/'],
#  'Kevin Reynolds': ['/name/nm0721817/'],
#  'Paul W.S. Anderson': ['/name/nm0027271/'],
#  'Sam Mendes': ['/name/nm0005222/'],
#  'Dee Rees': ['/name/nm2011696/'],
#  'Thomas Vinterberg': ['/name/nm0899121/'],
#  'Marc Munden': ['/name/nm0612720/'],
#  'Walter Hill': ['/name/nm0001353/'],
#  'Ron Clements': ['/name/nm0166256/'],
#  'Anne Fletcher': ['/name/nm0281945/'],
#  'Gary Fleder': ['/name/nm0001219/'],
#  'Terry Gilliam': ['/name/nm0000416/'],
#  'John Huston': ['/name/nm0001379/'],
#  'Mike Nichols': ['/name/nm0001566/'],
#  'Peter Weir': ['/name/nm0001837/'],
#  'Frank Coraci': ['/name/nm0178997/'],
#  'Hany Abu-Assad': ['/name/nm0009463/'],
#  'Elizabeth Allen Rosenbaum': ['/name/nm0020491/'],
#  'William Wyler': ['/name/nm0943758/'],
#  'Brad Silberling': ['/name/nm0797869/'],
#  'Scott Frank': ['/name/nm0291082/'],
#  'Roger Donaldson': ['/name/nm0002044/'],
#  'Terrence Malick': ['/name/nm0000517/'],
#  'Jack Garfein': ['/name/nm0307246/'],
#  'Burr Steers': ['/name/nm0824882/'],
#  'Brett Haley': ['/name/nm1417640/'],
#  'Justin Chadwick': ['/name/nm0149491/'],
#  'Penny Marshall': ['/name/nm0001508/'],
#  'Stephen Daldry': ['/name/nm0197636/'],
#  'J Blakeson': ['/name/nm2128335/'],
#  'Andrew Stanton': ['/name/nm0004056/'],
#  'Gregory Wilson': ['/name/nm0933471/'],
#  'Gore Verbinski': ['/name/nm0893659/'],
#  'Harald Zwart': ['/name/nm0958969/'],
#  'Roman Polanski': ['/name/nm0000591/'],
#  'Thor Freudenthal': ['/name/nm0294457/'],
#  'Brad Peyton': ['/name/nm0679031/'],
#  'Robert Mulligan': ['/name/nm0612322/'],
#  'Gavin Hood': ['/name/nm0004303/'],
#  'Blake Edwards': ['/name/nm0001175/'],
#  'Todd Field': ['/name/nm0276062/'],
#  'John Sturges': ['/name/nm0836328/'],
#  'Adam Shankman': ['/name/nm0788202/'],
#  'Luc Besson': ['/name/nm0000108/'],
#  'David Koepp': ['/name/nm0462895/'],
#  'Paul Michael Glaser': ['/name/nm0001274/'],
#  'Zak Hilditch': ['/name/nm1991847/'],
#  'Andrew Davis': ['/name/nm0001112/'],
#  'Don Siegel': ['/name/nm0796923/'],
#  'Frank Miller': ['/name/nm0588340/'],
#  'Shawn Levy': ['/name/nm0506613/'],
#  'Luke Snellin': ['/name/nm2866226/'],
#  'Sebastián Lelio': ['/name/nm0133326/'],
#  'Stefen Fangmeier': ['/name/nm0266777/'],
#  'Gabor Csupo': ['/name/nm0190780/'],
#  'Susan Johnson': ['/name/nm0426287/'],
#  'Lone Scherfig': ['/name/nm0771054/'],
#  'John Schlesinger': ['/name/nm0772259/'],
#  'Michael Apted': ['/name/nm0000776/'],
#  'Marcus Nispel': ['/name/nm1197971/'],
#  'Mark Herman': ['/name/nm0379179/'],
#  'Scott Kalvert': ['/name/nm0436284/'],
#  'Matt Reeves': ['/name/nm0716257/'],
#  'Richard Donner': ['/name/nm0001149/'],
#  'Paul McGuigan': ['/name/nm0006476/'],
#  'Chris Miller': ['/name/nm1844237/'],
#  'Jason Reitman': ['/name/nm0718646/'],
#  'Robert Schwentke': ['/name/nm0777881/'],
#  'John Glen': ['/name/nm0322515/'],
#  'Spike Jonze': ['/name/nm0005069/'],
#  'Paul Dano': ['/name/nm0200452/'],
#  'Phillip Noyce': ['/name/nm0637518/'],
#  'Kirk Jones': ['/name/nm0428600/'],
#  'Randall Wallace': ['/name/nm0908824/'],
#  'Giuseppe Capotondi': ['/name/nm3321297/'],
#  'Steven Soderbergh': ['/name/nm0001752/'],
#  'Barry Jenkins': ['/name/nm1503575/'],
#  'Jon S. Baird': ['/name/nm1580671/'],
#  'Mel Brooks': ['/name/nm0000316/'],
#  'Kimberly Peirce': ['/name/nm0005303/'],
#  'George Pal': ['/name/nm0657162/'],
#  'Wolfgang Reitherman': ['/name/nm0718627/'],
#  'Gilles Paquet-Brenner': ['/name/nm0660707/'],
#  'Cecil B. DeMille': ['/name/nm0001124/'],
#  'George Roy Hill': ['/name/nm0001351/'],
#  'Henry Selick': ['/name/nm0783139/'],
#  'Harold Becker': ['/name/nm0000887/'],
#  'Alex Proyas': ['/name/nm0001639/'],
#  'Cary Joji Fukunaga': ['/name/nm1560977/'],
#  'Bille Woodruff': ['/name/nm0937306/'],
#  'Garth Jennings': ['/name/nm1134029/'],
#  'Alan J. Pakula': ['/name/nm0001587/'],
#  'Richard LaGravenese': ['/name/nm0481418/'],
#  'David Swift': ['/name/nm0842582/'],
#  'Derek Cianfrance': ['/name/nm0161834/'],
#  'Florent-Emilio Siri': ['/name/nm0802807/'],
#  'Paul King': ['/name/nm1653753/'],
#  'Fernando Meirelles': ['/name/nm0576987/'],
#  'James Bobin': ['/name/nm0090386/'],
#  'Eli Roth': ['/name/nm0744834/'],
#  'Barry Levinson': ['/name/nm0001469/'],
#  'Mark Waters': ['/name/nm0914132/'],
#  'Shane Black': ['/name/nm0000948/'],
#  'Franklin J. Schaffner': ['/name/nm0769874/'],
#  'Mathew Cullen': ['/name/nm3810122/'],
#  'Ramin Bahrani': ['/name/nm1023919/'],
#  'Beeban Kidron': ['/name/nm0452319/'],
#  'Danis Tanovic': ['/name/nm0849786/'],
#  'Chris Buck': ['/name/nm0118333/'],
#  'James Franco': ['/name/nm0290556/'],
#  'Debra Granik': ['/name/nm0335138/'],
#  'Agnieszka Holland': ['/name/nm0002140/'],
#  'James Watkins': ['/name/nm1220140/'],
#  'George Tillman Jr.': ['/name/nm0863387/'],
#  'James Kent': ['/name/nm0448757/'],
#  'Charles Martin Smith': ['/name/nm0001747/'],
#  'Richard Fleischer': ['/name/nm0281507/'],
#  'James Wong': ['/name/nm0939128/'],
#  'Ryan Murphy': ['/name/nm0614682/'],
#  'Stephen Herek': ['/name/nm0378893/'],
#  'Barry Sonnenfeld': ['/name/nm0001756/'],
#  'Phil Alden Robinson': ['/name/nm0004675/'],
#  'Sam Raimi': ['/name/nm0000600/'],
#  'Eric Brevig': ['/name/nm0108094/'],
#  'Michael Hoffman': ['/name/nm0001355/'],
#  'Michael Anderson': ['/name/nm0027183/'],
#  'Andrew Niccol': ['/name/nm0629272/'],
#  'Melville Shavelson': ['/name/nm0789520/'],
#  'David Cronenberg': ['/name/nm0000343/'],
#  'Kaige Chen': ['/name/nm0155280/'],
#  'James L. Brooks': ['/name/nm0000985/'],
#  'Simon Curtis': ['/name/nm0193508/'],
#  'Kevin Kölsch': ['/name/nm1556116/'],
#  'Michael Cristofer': ['/name/nm0188165/'],
#  'Jonathan Levine': ['/name/nm1349522/'],
#  'Ross Katz': ['/name/nm0441839/'],
#  'Robert Altman': ['/name/nm0000265/'],
#  'Jim Gillespie': ['/name/nm0318947/'],
#  'Jeff Baena': ['/name/nm1337885/'],
#  'Andy Serkis': ['/name/nm0785227/'],
#  'Scott Stewart': ['/name/nm0829820/'],
#  'Val Guest': ['/name/nm0346436/'],
#  'Gary Trousdale': ['/name/nm0873779/'],
#  'Franco Zeffirelli': ['/name/nm0001874/'],
#  'Phil Karlson': ['/name/nm0439597/'],
#  'Christian Ditter': ['/name/nm0228542/'],
#  'Jesse Peretz': ['/name/nm0673400/'],
#  'Alan Parker': ['/name/nm0000570/'],
#  'Kevin Macdonald': ['/name/nm0531817/'],
#  'Richard Eyre': ['/name/nm0264236/'],
#  'Henry Joost': ['/name/nm1160962/'],
#  'Henry Hathaway': ['/name/nm0368871/'],
#  'Joseph L. Mankiewicz': ['/name/nm0000581/'],
#  'John Carpenter': ['/name/nm0000118/'],
#  'Andy Fickman': ['/name/nm0275698/'],
#  'Arthur Hiller': ['/name/nm0002137/'],
#  'Peter Bogdanovich': ['/name/nm0000953/'],
#  'Robert Benton': ['/name/nm0000914/'],
#  'Alexandre Aja': ['/name/nm0014960/'],
#  'Ry Russo-Young': ['/name/nm1735543/'],
#  'Ken Kwapis': ['/name/nm0477129/'],
#  'W.S. Van Dyke': ['/name/nm0886754/'],
#  'Richard Linklater': ['/name/nm0000500/'],
#  'Peter Tewksbury': ['/name/nm0856715/'],
#  'Vincenzo Natali': ['/name/nm0622112/'],
#  "Tommy O'Haver": ['/name/nm0641373/'],
#  'Ralph Bakshi': ['/name/nm0000835/'],
#  'R.J. Cutler': ['/name/nm0191712/'],
#  'Chris Noonan': ['/name/nm0003088/'],
#  'Jon Avnet': ['/name/nm0000816/'],
#  'Frank Marshall': ['/name/nm0550881/'],
#  'Stephen Norrington': ['/name/nm0635759/'],
#  'Robert Aldrich': ['/name/nm0000736/'],
#  'Breck Eisner': ['/name/nm0252135/'],
#  'Peter Yates': ['/name/nm0946811/'],
#  'Rowan Joffe': ['/name/nm0423626/'],
#  'Michael Caton-Jones': ['/name/nm0001994/'],
#  'Paul T. Scheuring': ['/name/nm0771228/'],
#  'Robert Redford': ['/name/nm0000602/'],
#  'Ava DuVernay': ['/name/nm1148550/'],
#  'Lee Tamahori': ['/name/nm0848414/'],
#  'Roger Avary': ['/name/nm0000812/'],
#  'John Frankenheimer': ['/name/nm0001239/'],
#  'Alfonso Gomez-Rejon': ['/name/nm0004234/'],
#  'Volker Schlöndorff': ['/name/nm0772522/'],
#  'Brad Bird': ['/name/nm0083348/'],
#  'Timur Bekmambetov': ['/name/nm0067457/'],
#  'David Bowers': ['/name/nm0101047/'],
#  'William A. Graham': ['/name/nm0334353/'],
#  'Scott Hicks': ['/name/nm0382956/'],
#  'James Bridges': ['/name/nm0108745/'],
#  'Walter Murch': ['/name/nm0004555/'],
#  'John Guillermin': ['/name/nm0347086/'],
#  'Greg Barker': ['/name/nm0994499/'],
#  'Duwayne Dunham': ['/name/nm0242271/'],
#  'George Miller': ['/name/nm0004306/'],
#  'Daniel Espinosa': ['/name/nm1174251/'],
#  'Anna Boden': ['/name/nm1349818/'],
#  'Claire McCarthy': ['/name/nm2113122/'],
#  'Vincent Ward': ['/name/nm0911910/'],
#  'Lewis Teague': ['/name/nm0853546/'],
#  'Shana Feste': ['/name/nm0275277/'],
#  'Hal Ashby': ['/name/nm0000797/'],
#  'Saul Dibb': ['/name/nm1314116/'],
#  'Lee Daniels': ['/name/nm0200005/'],
#  'Charles Shyer': ['/name/nm0796124/'],
#  'Mary Lambert': ['/name/nm0005116/'],
#  'Brian Percival': ['/name/nm1093053/'],
#  'Henry Koster': ['/name/nm0467396/'],
#  'Jane Campion': ['/name/nm0001005/'],
#  'James Ivory': ['/name/nm0412465/'],
#  'Tim Johnson': ['/name/nm0426333/'],
#  'Joseph Ruben': ['/name/nm0747849/'],
#  'Mélanie Laurent': ['/name/nm0491259/'],
#  'Simon West': ['/name/nm0922346/'],
#  'Akiva Goldsman': ['/name/nm0326040/'],
#  'Pierre Morel': ['/name/nm0603628/'],
#  'Rob Letterman': ['/name/nm1224299/'],
#  'Sergei Bodrov': ['/name/nm0091076/'],
#  'Roger Christian': ['/name/nm0002337/'],
#  'George P. Cosmatos': ['/name/nm0181902/'],
#  'Marielle Heller': ['/name/nm1716636/'],
#  'Matt Williams': ['/name/nm0931285/'],
#  'Rob Cohen': ['/name/nm0003418/'],
#  'John Ford': ['/name/nm0000406/'],
#  'Carter Smith': ['/name/nm2127650/'],
#  'Simon Wells': ['/name/nm0920425/'],
#  'Iain Softley': ['/name/nm0812200/'],
#  'Brian G. Hutton': ['/name/nm0404606/'],
#  'John Madden': ['/name/nm0006960/'],
#  'Billy Wilder': ['/name/nm0000697/'],
#  'Jack Clayton': ['/name/nm0002338/'],
#  'Cédric Jimenez': ['/name/nm1473428/'],
#  'Clyde Geronimi': ['/name/nm0314671/'],
#  'Stuart Hazeldine': ['/name/nm0371955/'],
#  'Gus Van Sant': ['/name/nm0001814/'],
#  'Michael Winner': ['/name/nm0935382/'],
#  'Babak Anvari': ['/name/nm2035118/'],
#  'Vincente Minnelli': ['/name/nm0591486/'],
#  'Richard Glatzer': ['/name/nm0322144/'],
#  'Robert Moore': ['/name/nm0601800/'],
#  'Anton Corbijn': ['/name/nm0179221/'],
#  'Brian Helgeland': ['/name/nm0001338/'],
#  'Victor Saville': ['/name/nm0767701/'],
#  'Wayne Wang': ['/name/nm0911061/'],
#  'Peter Webber': ['/name/nm0916424/'],
#  'John Singleton': ['/name/nm0005436/'],
#  'Philip Kaufman': ['/name/nm0442241/'],
#  'Stephen J. Anderson': ['/name/nm0027459/'],
#  'Peter Askin': ['/name/nm0039468/'],
#  'Michael Ritchie': ['/name/nm0006916/'],
#  'Sean Penn': ['/name/nm0000576/'],
#  'F. Gary Gray': ['/name/nm0336620/'],
#  'Sam Peckinpah': ['/name/nm0001603/'],
#  'Raja Gosnell': ['/name/nm0331532/'],
#  'Barbet Schroeder': ['/name/nm0775447/'],
#  'Andrew Douglas': ['/name/nm1497918/'],
#  'Tom Holland': ['/name/nm0276169/'],
#  'Spike Lee': ['/name/nm0000490/'],
#  'Walter Salles': ['/name/nm0758574/'],
#  'Stella Meghie': ['/name/nm4907810/'],
#  'Martin Ritt': ['/name/nm0728688/'],
#  'David Leveaux': ['/name/nm1659505/'],
#  'Rob Minkoff': ['/name/nm0591450/'],
#  'Charles Laughton': ['/name/nm0001452/'],
#  'Norman Ferguson': ['/name/nm0272568/'],
#  'Marek Kanievska': ['/name/nm0437709/'],
#  'Robin Swicord': ['/name/nm0842523/'],
#  'George Scribner': ['/name/nm0780117/'],
#  'Jan de Bont': ['/name/nm0000957/'],
#  'Joe Roth': ['/name/nm0005387/'],
#  'Betty Thomas': ['/name/nm0858525/'],
#  'Ernst Lubitsch': ['/name/nm0523932/'],
#  'Audrey Wells': ['/name/nm0920108/'],
#  'Harry Hook': ['/name/nm0393591/'],
#  'Hugh Wilson': ['/name/nm0933505/'],
#  'Jennifer Yuh Nelson': ['/name/nm0950775/'],
#  'Ted Berman': ['/name/nm0075859/'],
#  'Jake Schreier': ['/name/nm1500577/'],
#  'Michael Rymer': ['/name/nm0753382/'],
#  'Vic Armstrong': ['/name/nm0002184/'],
#  'Miguel Sapochnik': ['/name/nm0764601/'],
#  'Gary Sinise': ['/name/nm0000641/'],
#  'Lawrence Kasdan': ['/name/nm0001410/'],
#  'Fred Zinnemann': ['/name/nm0003593/'],
#  'Kevin Pollak': ['/name/nm0001629/'],
#  'John Moore': ['/name/nm0601382/'],
#  'Ron Maxwell': ['/name/nm0561813/'],
#  'Dean Parisot': ['/name/nm0661751/'],
#  'Daniel Attias': ['/name/nm0003733/'],
#  'Norman Jewison': ['/name/nm0422484/'],
#  'Michael Engler': ['/name/nm0257554/'],
#  'Vadim Perelman': ['/name/nm1166926/'],
#  'Orson Welles': ['/name/nm0000080/'],
#  'Dennis Hopper': ['/name/nm0000454/'],
#  'Elliott Lester': ['/name/nm1714255/'],
#  'Ken Annakin': ['/name/nm0002175/'],
#  'Ken Russell': ['/name/nm0001692/'],
#  'Clive Barker': ['/name/nm0000850/'],
#  'George Stevens': ['/name/nm0828419/'],
#  'Mervyn LeRoy': ['/name/nm0503777/'],
#  'Tommy Lee Jones': ['/name/nm0000169/'],
#  'Peter Hyams': ['/name/nm0001382/'],
#  'Robert Rossen': ['/name/nm0744035/'],
#  'Paul Weitz': ['/name/nm0919369/'],
#  'Julie Anne Robinson': ['/name/nm1455688/'],
#  'Tod Williams': ['/name/nm0931095/'],
#  'Wash Westmoreland': ['/name/nm0922903/'],
#  'Stephen Kay': ['/name/nm0443181/'],
#  'Drew Barrymore': ['/name/nm0000106/'],
#  'Gregg Araki': ['/name/nm0000777/'],
#  'Craig Zobel': ['/name/nm0957505/'],
#  'Michael Curtiz': ['/name/nm0002031/'],
#  'Scott Cooper': ['/name/nm0178376/'],
#  'Carl Franklin': ['/name/nm0002083/'],
#  'Gurinder Chadha': ['/name/nm0149446/'],
#  'Elia Kazan': ['/name/nm0001415/'],
#  'Joan Micklin Silver': ['/name/nm0798717/'],
#  'Frank Oz': ['/name/nm0000568/'],
#  'J. Lee Thompson': ['/name/nm0496746/'],
#  'Richard Brooks': ['/name/nm0112218/'],
#  'Brian Henson': ['/name/nm0005008/'],
#  'Michael Reeves': ['/name/nm0716262/'],
#  'Daniel Barnz': ['/name/nm1400426/'],
#  'Barbra Streisand': ['/name/nm0000659/'],
#  'Michael Grandage': ['/name/nm0334787/'],
#  'Gary Winick': ['/name/nm0935095/'],
#  'Howard Hawks': ['/name/nm0001328/'],
#  'Bruce Robinson': ['/name/nm0732430/'],
#  'George Sluizer': ['/name/nm0806293/'],
#  'Otto Preminger': ['/name/nm0695937/'],
#  'Ricky Staub': ['/name/nm2598995/'],
#  'Joe Alves': ['/name/nm0023469/'],
#  'Christian Marquand': ['/name/nm0549650/'],
#  'Josef Rusnak': ['/name/nm0750857/'],
#  'Bertrand Tavernier': ['/name/nm0851724/'],
#  'Jay Russell': ['/name/nm0751221/'],
#  'James Whale': ['/name/nm0001843/'],
#  'Rouben Mamoulian': ['/name/nm0541149/'],
#  'Peter Sollett': ['/name/nm0813164/'],
#  'Peter Kosminsky': ['/name/nm0467225/'],
#  'Lewis Milestone': ['/name/nm0587277/'],
#  'John Curran': ['/name/nm0192845/'],
#  'Mimi Leder': ['/name/nm0001460/'],
#  'Mark Robson': ['/name/nm0733476/'],
#  'Brian DeCubellis': ['/name/nm1802093/'],
#  'Michael Sucsy': ['/name/nm1302591/'],
#  'Edwin L. Marin': ['/name/nm0547446/'],
#  'Susanna White': ['/name/nm1264352/'],
#  'Mark Mylod': ['/name/nm0617042/'],
#  'Sara Sugarman': ['/name/nm0837406/'],
#  'Jeannot Szwarc': ['/name/nm0844358/'],
#  'Luis Llosa': ['/name/nm0515891/'],
#  'Thomas Bezucha': ['/name/nm0080120/'],
#  'Daniel Petrie Jr.': ['/name/nm0677943/'],
#  'William A. Wellman': ['/name/nm0920074/'],
#  'Barry Alexander Brown': ['/name/nm0113084/'],
#  'James Algar': ['/name/nm0019282/'],
#  'Sylvio Tabet': ['/name/nm0845973/'],
#  'Nora Twomey': ['/name/nm1316072/'],
#  'Don Bluth': ['/name/nm0089940/'],
#  'Geoffrey Sax': ['/name/nm0768249/'],
#  'Ami Canaan Mann': ['/name/nm0542642/'],
#  'Clark Johnson': ['/name/nm0424800/'],
#  'Ted Post': ['/name/nm0692872/'],
#  'Richard Benjamin': ['/name/nm0000907/'],
#  'James Wan': ['/name/nm1490123/'],
#  'Lucky McKee': ['/name/nm1031246/'],
#  'Joseph Kane': ['/name/nm0437356/'],
#  'Mira Nair': ['/name/nm0619762/'],
#  'Carl Reiner': ['/name/nm0005348/'],
#  'Henry Levin': ['/name/nm0505610/'],
#  'Andrzej Bartkowiak': ['/name/nm0005647/'],
#  'Arthur Penn': ['/name/nm0671957/'],
#  'Gil Kenan': ['/name/nm1481493/'],
#  'Hossein Amini': ['/name/nm0024925/'],
#  'Ubaldo Ragona': ['/name/nm0706575/'],
#  'Pella Kagerman': ['/name/nm2445423/'],
#  'Mark Pellington': ['/name/nm0671210/'],
#  'Tod Browning': ['/name/nm0115218/'],
#  'Ewan McGregor': ['/name/nm0000191/'],
#  'Stacie Passon': ['/name/nm4945419/'],
#  'Bille August': ['/name/nm0000806/'],
#  'George Seaton': ['/name/nm0780833/'],
#  'William Peter Blatty': ['/name/nm0087861/'],
#  'Ulu Grosbard': ['/name/nm0343260/'],
#  'Oliver Hirschbiegel': ['/name/nm0386570/'],
#  'Ray Enright': ['/name/nm0258015/'],
#  'Joe Dante': ['/name/nm0001102/'],
#  'Oren Moverman': ['/name/nm0610219/'],
#  'John Schultz': ['/name/nm0776271/'],
#  'Ralph Nelson': ['/name/nm0625680/'],
#  'Boris Sagal': ['/name/nm0755963/'],
#  'Tom Vaughan': ['/name/nm0891114/'],
#  'Stephen Hopkins': ['/name/nm0394280/'],
#  'Johnny Martin': ['/name/nm0552565/'],
#  'Jules Bass': ['/name/nm0060072/'],
#  'Michael Sarne': ['/name/nm0765398/'],
#  'Elliot Silverstein': ['/name/nm0799033/'],
#  'Stacy Title': ['/name/nm0864468/'],
#  'Kevin Lima': ['/name/nm0510674/'],
#  'Dan Wolman': ['/name/nm0938630/'],
#  'Sanaa Hamri': ['/name/nm1065402/'],
#  'Michael Carreras': ['/name/nm0140257/'],
#  'John Hough': ['/name/nm0396421/'],
#  'Walter Lang': ['/name/nm0485943/'],
#  'Nicholas Ray': ['/name/nm0712947/'],
#  'Peter Chelsom': ['/name/nm0155093/'],
#  'David Soren': ['/name/nm1659741/'],
#  'Meg Ryan': ['/name/nm0000212/'],
#  'Miguel Arteta': ['/name/nm0037708/'],
#  'Fred Schepisi': ['/name/nm0770961/'],
#  'Bretaigne Windust': ['/name/nm0934827/'],
#  'Jonathan Mostow': ['/name/nm0609236/'],
#  'Byron Haskin': ['/name/nm0005738/'],
#  'Jeffrey Bloom': ['/name/nm0089177/'],
#  'Michael O. Sajbel': ['/name/nm0756935/'],
#  'Charlie Stratton': ['/name/nm0771613/'],
#  'Douglas Sirk': ['/name/nm0802862/'],
#  'Bharat Nalluri': ['/name/nm0620576/'],
#  'Tony Goldwyn': ['/name/nm0001282/'],
#  'Bob Rafelson': ['/name/nm0706182/'],
#  'Mike Mitchell': ['/name/nm0593610/'],
#  'Wim Wenders': ['/name/nm0000694/'],
#  'Jennifer Flackett': ['/name/nm0280814/'],
#  'Betty Kaplan': ['/name/nm0438201/'],
#  'King Vidor': ['/name/nm0896542/'],
#  'Scott Waugh': ['/name/nm0915304/'],
#  'Derick Martini': ['/name/nm0553796/'],
#  'Bryan Forbes': ['/name/nm0285302/'],
#  'Richard Lester': ['/name/nm0504513/'],
#  'Ed Harris': ['/name/nm0000438/'],
#  'Arne Glimcher': ['/name/nm0322865/'],
#  'Roland Joffé': ['/name/nm0423646/'],
#  'Brian Gibson': ['/name/nm0001270/'],
#  'Billy Bob Thornton': ['/name/nm0000671/'],
#  'Gina Prince-Bythewood': ['/name/nm0697656/'],
#  'Caroline Thompson': ['/name/nm0003031/'],
#  'Sidney J. Furie': ['/name/nm0002089/'],
#  'Alan Myerson': ['/name/nm0002887/'],
#  'Julian Jarrold': ['/name/nm0418982/'],
#  'Fraser C. Heston': ['/name/nm0381699/'],
#  'Edward Dmytryk': ['/name/nm0229424/'],
#  'Jerry Jameson': ['/name/nm0417054/'],
#  'Mark L. Lester': ['/name/nm0504495/'],
#  'Hideo Nakata': ['/name/nm0620378/'],
#  'John G. Avildsen': ['/name/nm0000814/'],
#  'Jason Hall': ['/name/nm0355699/'],
#  'Mark Rydell': ['/name/nm0041932/'],
#  'George C. Wolfe': ['/name/nm0938045/'],
#  'Guillaume Canet': ['/name/nm0133899/'],
#  'Paul Johansson': ['/name/nm0424035/'],
#  'Michael Winterbottom': ['/name/nm0935863/'],
#  'David S. Goyer': ['/name/nm0275286/'],
#  'Forest Whitaker': ['/name/nm0001845/'],
#  'Henry King': ['/name/nm0454771/'],
#  'Terry George': ['/name/nm0313623/'],
#  'Edgar G. Ulmer': ['/name/nm0880618/'],
#  'Morton DaCosta': ['/name/nm0196536/'],
#  'Joseph Sargent': ['/name/nm0765121/'],
#  'Gregor Jordan': ['/name/nm0429964/'],
#  'Carroll Ballard': ['/name/nm0050597/'],
#  'Luis Mandoki': ['/name/nm0001502/'],
#  'Stanley Kramer': ['/name/nm0006452/'],
#  'Shari Springer Berman': ['/name/nm0075849/'],
#  'Roger Michell': ['/name/nm0585011/'],
#  'Mel Gibson': ['/name/nm0000154/'],
#  'Bernard Rose': ['/name/nm0741262/'],
#  'Michael Chapman': ['/name/nm0152469/'],
#  'Paul Schrader': ['/name/nm0001707/'],
#  'Burt Kennedy': ['/name/nm0447944/'],
#  'Marlon Brando': ['/name/nm0000008/'],
#  'Uli Edel': ['/name/nm0248942/'],
#  'Jon Amiel': ['/name/nm0000750/'],
#  'Jamie Blanks': ['/name/nm0087595/'],
#  'Michael Crichton': ['/name/nm0000341/'],
#  'Melanie Mayron': ['/name/nm0563039/'],
#  'Scott Teems': ['/name/nm1802374/'],
#  'Gordon Parks': ['/name/nm0662953/'],
#  'John Stephenson': ['/name/nm0827268/'],
#  'William Teitler': ['/name/nm0854074/'],
#  'Lance Mungia': ['/name/nm0612812/'],
#  'Matt Cimber': ['/name/nm0162343/'],
#  'Gregory La Cava': ['/name/nm0478441/'],
#  'Jack Smight': ['/name/nm0806915/'],
#  'Albert Lewin': ['/name/nm0506797/'],
#  'Jacques Tourneur': ['/name/nm0869664/'],
#  'Andrew Sipes': ['/name/nm0802617/'],
#  'Nicholas Meyer': ['/name/nm0583292/'],
#  'Eric D. Howell': ['/name/nm0397970/'],
#  'Eric Red': ['/name/nm0714599/'],
#  'Sophie Barthes': ['/name/nm1754436/'],
#  'George Armitage': ['/name/nm0000786/'],
#  'Fritz Lang': ['/name/nm0000485/'],
#  'Bronwen Hughes': ['/name/nm0400486/'],
#  'L.Q. Jones': ['/name/nm0428618/'],
#  'George Sidney': ['/name/nm0796645/'],
#  'Alex Pettyfer': ['/name/nm1641117/'],
#  'Guy Hamilton': ['/name/nm0357891/'],
#  'Stuart Millar': ['/name/nm0587706/'],
#  'John Stevenson': ['/name/nm0828970/'],
#  'Shainee Gabel': ['/name/nm0300015/'],
#  'Hal Needham': ['/name/nm0624102/'],
#  'Peter Douglas': ['/name/nm0235209/'],
#  'Graham Annable': ['/name/nm0030253/'],
#  'Joe Chappelle': ['/name/nm0152640/'],
#  'Joy Batchelor': ['/name/nm0060742/'],
#  'William Monahan': ['/name/nm1184258/'],
#  'Scott Speer': ['/name/nm1228976/'],
#  'Hector Babenco': ['/name/nm0002199/'],
#  'Jessica Sharzer': ['/name/nm0789366/'],
#  'Shekhar Kapur': ['/name/nm0001408/'],
#  'Daniel Alfredson': ['/name/nm0019242/'],
#  'Richard Thorpe': ['/name/nm0861703/'],
#  'Michael Cacoyannis': ['/name/nm0128050/'],
#  'John M. Stahl': ['/name/nm0821472/'],
#  'Danny Strong': ['/name/nm0834960/'],
#  'Michael Cimino': ['/name/nm0001047/'],
#  'Mark Steven Johnson': ['/name/nm0425756/'],
#  'Victor Salva': ['/name/nm0759207/'],
#  'Tony Richardson': ['/name/nm0724798/'],
#  'Annette Haywood-Carter': ['/name/nm0371852/'],
#  'Donald Cammell': ['/name/nm0131910/'],
#  'Wes Craven': ['/name/nm0000127/'],
#  'Mathieu Kassovitz': ['/name/nm0440913/'],
#  'Bobby Farrelly': ['/name/nm0125803/'],
#  'Daniel Schechter': ['/name/nm1633080/'],
#  'Joseph M. Newman': ['/name/nm0628149/'],
#  'Susan Seidelman': ['/name/nm0782384/'],
#  'Frederik Du Chau': ['/name/nm0238865/'],
#  'Preston A. Whitmore II': ['/name/nm0926211/'],
#  'Nick Love': ['/name/nm0522393/'],
#  'Nicholas Hytner': ['/name/nm0405336/'],
#  'Dalton Trumbo': ['/name/nm0874308/'],
#  'Norman Tokar': ['/name/nm0865709/'],
#  'Rebecca Miller': ['/name/nm0589182/'],
#  'Robert Z. Leonard': ['/name/nm0502752/'],
#  'René Clair': ['/name/nm0163229/'],
#  'Donna Deitch': ['/name/nm0215123/'],
#  'Geoff Murphy': ['/name/nm0614276/'],
#  'Johnny Depp': ['/name/nm0000136/'],
#  'Nicole Holofcener': ['/name/nm0392237/'],
#  'John Putch': ['/name/nm0003289/'],
#  'Scott McGehee': ['/name/nm0569166/'],
#  'Sam Fell': ['/name/nm0271402/'],
#  'Gary David Goldberg': ['/name/nm0325204/'],
#  'Eric Valette': ['/name/nm0884659/'],
#  'Howard Franklin': ['/name/nm0291442/'],
#  'Katt Shea': ['/name/nm0002240/'],
#  'Frank Lloyd': ['/name/nm0515979/'],
#  'Jocelyn Moorhouse': ['/name/nm0602104/'],
#  'Liev Schreiber': ['/name/nm0000630/'],
#  'David R. Ellis': ['/name/nm0254786/'],
#  'Charles A. Nichols': ['/name/nm0629363/'],
#  'Keith Gordon': ['/name/nm0330360/'],
#  'Haifaa Al-Mansour': ['/name/nm2223783/'],
#  'Kriv Stenders': ['/name/nm0826541/'],
#  'George Sherman': ['/name/nm0792450/'],
#  'Stuart Heisler': ['/name/nm0374702/'],
#  'Joshua Logan': ['/name/nm0517597/'],
#  'Norman Taurog': ['/name/nm0851537/'],
#  'Richard Rush': ['/name/nm0750701/'],
#  'James Schamus': ['/name/nm0770005/'],
#  'Lili Fini Zanuck': ['/name/nm0005572/'],
#  'Rod Hardy': ['/name/nm0362738/'],
#  'George Cukor': ['/name/nm0002030/'],
#  'Bob Gosse': ['/name/nm0331606/'],
#  'Stephan Elliott': ['/name/nm0254632/'],
#  'Jean Negulesco': ['/name/nm0624535/'],
#  'Amy Berg': ['/name/nm1332844/'],
#  'Craig Bolotin': ['/name/nm0093271/'],
#  'John Irvin': ['/name/nm0410139/'],
#  'Steve Barron': ['/name/nm0006625/'],
#  'Jefery Levy': ['/name/nm0506461/'],
#  'Daniel Mann': ['/name/nm0542702/'],
#  'Don Taylor': ['/name/nm0852279/'],
#  'Abel Ferrara': ['/name/nm0001206/'],
#  'Wil Shriner': ['/name/nm0795407/'],
#  'Tay Garnett': ['/name/nm0307819/'],
#  'Joe Pytka': ['/name/nm0701592/'],
#  'Delmer Daves': ['/name/nm0202681/'],
#  'Tom Gries': ['/name/nm0340981/'],
#  'Philip Haas': ['/name/nm0351993/'],
#  'William Dieterle': ['/name/nm0226189/'],
#  'Pamela Romanowsky': ['/name/nm2408871/'],
#  'Callie Khouri': ['/name/nm0451884/'],
#  'Buzz Kulik': ['/name/nm0474539/'],
#  'George A. Romero': ['/name/nm0001681/'],
#  'Gary Nelson': ['/name/nm0625379/'],
#  'Jack Arnold': ['/name/nm0000791/'],
#  'Lewis John Carlino': ['/name/nm0137573/'],
#  'Lewis Allen': ['/name/nm0020765/'],
#  'Dan Curtis': ['/name/nm0193303/'],
#  'Glen Morgan': ['/name/nm0604688/'],
#  'Martin Davidson': ['/name/nm0203429/'],
#  'Robin Budd': ['/name/nm1180460/'],
#  'Peter H. Hunt': ['/name/nm0402596/'],
#  'Roger Vadim': ['/name/nm0671862/'],
#  'Sam Weisman': ['/name/nm0918873/'],
#  'David L. Cunningham': ['/name/nm0192289/'],
#  'James Neilson': ['/name/nm0624809/'],
#  'Zalman King': ['/name/nm0455394/'],
#  'Courtney Solomon': ['/name/nm0813309/'],
#  'Louis King': ['/name/nm0003422/'],
#  'Reinhard Klooss': ['/name/nm0459996/'],
#  'Andrew V. McLaglen': ['/name/nm0572132/'],
#  'Laslo Benedek': ['/name/nm0070670/'],
#  'Irwin Allen': ['/name/nm0000740/'],
#  'Sam Wood': ['/name/nm0939992/'],
#  'David Seltzer': ['/name/nm0783544/'],
#  'Frank Perry': ['/name/nm0675068/'],
#  'Jean-Jacques Annaud': ['/name/nm0000269/'],
#  'Fritz Kiersch': ['/name/nm0452607/'],
#  'Paul Feig': ['/name/nm0082450/'],
#  'Don Roos': ['/name/nm0740400/'],
#  'Edward Drake': ['/name/nm4864836/'],
#  'Anjelica Huston': ['/name/nm0001378/'],
#  'Frank Tuttle': ['/name/nm0878338/'],
#  'Oliver Parker': ['/name/nm0662529/'],
#  'Harold Ramis': ['/name/nm0000601/'],
#  'Michael Mayer': ['/name/nm1555287/'],
#  'Stuart Orme': ['/name/nm0650233/'],
#  'Ari Folman': ['/name/nm0284369/'],
#  'Hy Averback': ['/name/nm0002195/'],
#  'Alexandre Espigares': ['/name/nm3115348/'],
#  'Martin Rosen': ['/name/nm0742034/'],
#  'Philippe Mora': ['/name/nm0602333/'],
#  'Rudolph Maté': ['/name/nm0005789/'],
#  'Steve Rash': ['/name/nm0711114/'],
#  'Burt Reynolds': ['/name/nm0000608/'],
#  'Dick Richards': ['/name/nm0724059/'],
#  "Pat O'Connor": ['/name/nm0640466/'],
#  'Kevin Connor': ['/name/nm0175428/'],
#  'Kevin Rodney Sullivan': ['/name/nm0838198/'],
#  'Henrik Ruben Genz': ['/name/nm0313227/'],
#  'Michael Polish': ['/name/nm0689187/'],
#  'Steve Trenbirth': ['/name/nm0872045/'],
#  'John D. Hancock': ['/name/nm0359386/'],
#  'Bob Spiers': ['/name/nm0818639/'],
#  'Allison Anders': ['/name/nm0025978/'],
#  'Angel Gracia': ['/name/nm0333471/'],
#  'Charles Sturridge': ['/name/nm0836430/'],
#  'Jim Mickle': ['/name/nm0585344/'],
#  'Stephen C. Apostolof': ['/name/nm0032154/'],
#  'David S. Ward': ['/name/nm0911486/'],
#  'Kathryn Bigelow': ['/name/nm0000941/'],
#  'James Manera': ['/name/nm2690726/'],
#  'John Fawcett': ['/name/nm0269502/'],
#  'Liliana Cavani': ['/name/nm0146960/'],
#  'Dean Semler': ['/name/nm0005871/'],
#  'Paul Newman': ['/name/nm0000056/'],
#  'Samuel Fuller': ['/name/nm0002087/'],
#  'William Tannen': ['/name/nm0849587/'],
#  'Neil LaBute': ['/name/nm0001438/'],
#  'Anthony Mann': ['/name/nm0542649/'],
#  'David Lowell Rich': ['/name/nm0723629/'],
#  'George Abbott': ['/name/nm0007973/'],
#  'Adriana Trigiani': ['/name/nm0872765/'],
#  'Cyrus Nowrasteh': ['/name/nm0637493/'],
#  'Michael Wadleigh': ['/name/nm0905579/'],
#  'Jules Dassin': ['/name/nm0202088/'],
#  'Bert I. Gordon': ['/name/nm0330026/'],
#  'Nathan Juran': ['/name/nm0432846/'],
#  'Ray Kellogg': ['/name/nm0446129/'],
#  'Lewis Gilbert': ['/name/nm0318150/'],
#  'André De Toth': ['/name/nm0211964/'],
#  'Charles Jarrott': ['/name/nm0418986/'],
#  'Zoltan Korda': ['/name/nm0466113/'],
#  'Euzhan Palcy': ['/name/nm0657484/'],
#  'François Girard': ['/name/nm0320660/'],
#  'Herbert Ross': ['/name/nm0006889/'],
#  'Earl Bellamy': ['/name/nm0068691/'],
#  'Jack Conway': ['/name/nm0176699/'],
#  'David M. Rosenthal': ['/name/nm1270033/'],
#  'Isabel Coixet': ['/name/nm0170043/'],
#  'Paul Wendkos': ['/name/nm0920862/'],
#  'John Cromwell': ['/name/nm0188669/'],
#  'Brian Gilbert': ['/name/nm0317981/'],
#  'Ida Lupino': ['/name/nm0526946/'],
#  'Dylan Kidd': ['/name/nm1071898/'],
#  'Jay Martin': ['/name/nm2371848/'],
#  'Raoul Walsh': ['/name/nm0909825/'],
#  'Budd Boetticher': ['/name/nm0091430/'],
#  'Marleen Gorris': ['/name/nm0331296/'],
#  'Jeremiah S. Chechik': ['/name/nm0154819/'],
#  'Antonio Banderas': ['/name/nm0000104/'],
#  'Carlo Carlei': ['/name/nm0137363/'],
#  'Steve Buscemi': ['/name/nm0000114/'],
#  'Robert Montgomery': ['/name/nm0599910/'],
#  'Mark Griffiths': ['/name/nm0341716/'],
#  'Norman Z. McLeod': ['/name/nm0572851/'],
#  'Stanley Donen': ['/name/nm0002045/'],
#  'Phil Joanou': ['/name/nm0423333/'],
#  'Gene Saks': ['/name/nm0757256/'],
#  'Robert Harling': ['/name/nm0363326/'],
#  'Emily Young': ['/name/nm1369721/'],
#  'Dick Powell': ['/name/nm0694090/'],
#  'Clarence Brown': ['/name/nm0113284/'],
#  'Oliver Schmitz': ['/name/nm0005628/'],
#  'Anand Tucker': ['/name/nm0875793/'],
#  'Lindsay Anderson': ['/name/nm0000755/'],
#  'Edmund Goulding': ['/name/nm0332539/'],
#  'George Marshall': ['/name/nm0550892/'],
#  'David Miller': ['/name/nm0588183/'],
#  'James Dearden': ['/name/nm0213139/'],
#  'H.C. Potter': ['/name/nm0693281/'],
#  'Sandra Nettelbeck': ['/name/nm0626686/'],
#  'Malcolm Mowbray': ['/name/nm0610261/'],
#  'Dwight H. Little': ['/name/nm0514546/'],
#  'Mike Mills': ['/name/nm0590122/'],
#  'John Milius': ['/name/nm0587518/'],
#  'Erle C. Kenton': ['/name/nm0448915/'],
#  'Robert Towne': ['/name/nm0001801/'],
#  'Patrick Stettner': ['/name/nm0828099/'],
#  'Charles Barton': ['/name/nm0059106/'],
#  'Joseph Pevney': ['/name/nm0678928/'],
#  'Chuck Russell': ['/name/nm0751080/'],
#  'István Szabó': ['/name/nm0843640/'],
#  'Richard C. Sarafian': ['/name/nm0764781/'],
#  'Andrew van den Houten': ['/name/nm0886156/'],
#  'Peter Maris': ['/name/nm0548059/'],
#  'Christopher Cain': ['/name/nm0128883/'],
#  'William Richert': ['/name/nm0724927/'],
#  'Rawson Marshall Thurber': ['/name/nm1098493/'],
#  'Stephen Milburn Anderson': ['/name/nm0027465/'],
#  'Katja von Garnier': ['/name/nm0902290/'],
#  'Robert Siodmak': ['/name/nm0802563/'],
#  'Terence Davies': ['/name/nm0203993/'],
#  'John Byrum': ['/name/nm0126440/'],
#  'Brett Leonard': ['/name/nm0502577/'],
#  'Gordon Douglas': ['/name/nm0235066/'],
#  'Ivan Passer': ['/name/nm0664852/'],
#  'John Glenn': ['/name/nm1726457/'],
#  'Bob Dolman': ['/name/nm0231190/'],
#  'Stanley R. Jaffe': ['/name/nm0415494/'],
#  'Helen Hunt': ['/name/nm0000166/'],
#  'Chris Eyre': ['/name/nm0264220/'],
#  'Jeremiah Zagar': ['/name/nm1476102/'],
#  'Bill Forsyth': ['/name/nm0287025/'],
#  'Todd Phillips': ['/name/nm0680846/'],
#  'Fletcher Markle': ['/name/nm0548529/'],
#  'Alexander Mackendrick': ['/name/nm0533241/'],
#  'Jack Cardiff': ['/name/nm0002153/'],
#  'Philip Harder': ['/name/nm0362136/'],
#  'Roy Ward Baker': ['/name/nm0001928/'],
#  'Frank D. Gilroy': ['/name/nm0319663/'],
#  'Arthur Lubin': ['/name/nm0523893/'],
#  'Carl Schenkel': ['/name/nm0770918/'],
#  'Lajos Koltai': ['/name/nm0005759/'],
#  'Kevin Bacon': ['/name/nm0000102/'],
#  'Roger Corman': ['/name/nm0000339/'],
#  'Clare Kilner': ['/name/nm0453270/'],
#  'Terence Young': ['/name/nm0950109/'],
#  'Mel Ferrer': ['/name/nm0002072/'],
#  'Burt Lancaster': ['/name/nm0000044/'],
#  'Piers Haggard': ['/name/nm0353592/'],
#  'Gillies MacKinnon': ['/name/nm0533564/'],
#  'Tim Hunter': ['/name/nm0006853/'],
#  'Fred M. Wilcox': ['/name/nm0928208/'],
#  'John Polson': ['/name/nm0689852/'],
#  'Francis Megahy': ['/name/nm0576283/'],
#  'William Marshall': ['/name/nm0550777/'],
#  'Peter Kassovitz': ['/name/nm0440914/'],
#  'Jack Nicholson': ['/name/nm0000197/'],
#  'Carol Reed': ['/name/nm0715346/'],
#  'Larry Peerce': ['/name/nm0670282/'],
#  'Ben Bolt': ['/name/nm0093322/'],
#  'John Roberts': ['/name/nm0731253/'],
#  'Javier Elorrieta': ['/name/nm0255546/'],
#  'Josef von Sternberg': ['/name/nm0903049/'],
#  'Corey Allen': ['/name/nm0001904/'],
#  'David Gordon Green': ['/name/nm0337773/'],
#  'Franco Amurri': ['/name/nm0002171/'],
#  'Barry Shear': ['/name/nm0790395/'],
#  'Alan Roberts': ['/name/nm0003085/'],
#  'James Clavell': ['/name/nm0165412/'],
#  'Andrew Black': ['/name/nm10509441/'],
#  'Douglas Heyes': ['/name/nm0382227/'],
#  'Robert Clouse': ['/name/nm0167195/'],
#  'Larry Cohen': ['/name/nm0169540/'],
#  'Paul Bogart': ['/name/nm0091575/'],
#  'James Goldstone': ['/name/nm0326360/'],
#  'Martin Sheen': ['/name/nm0000640/'],
#  'Michael Corrente': ['/name/nm0180912/'],
#  'Jim Clark': ['/name/nm0164083/'],
#  'Peter Ho-Sun Chan': ['/name/nm0151066/'],
#  'Leslie Greif': ['/name/nm0340037/'],
#  'Rhys Ernst': ['/name/nm3636870/'],
#  'Bruce Beresford': ['/name/nm0000915/'],
#  'Hampton Fancher': ['/name/nm0266684/'],
#  'Willard Huyck': ['/name/nm0404754/'],
#  'Peter Medak': ['/name/nm0575389/'],
#  'Martha Coolidge': ['/name/nm0004838/'],
#  'Frank Tashlin': ['/name/nm0850895/'],
#  'Gary Entin': ['/name/nm1925528/'],
#  'Edward Bernds': ['/name/nm0076618/'],
#  'John Hoffman': ['/name/nm0388971/'],
#  'Norman Mailer': ['/name/nm0537551/'],
#  'William Beaudine': ['/name/nm0064415/'],
#  'Don Chaffey': ['/name/nm0149548/'],
#  'Michelle Manning': ['/name/nm0543339/'],
#  'Michael Buster': ['/name/nm2147659/'],
#  'Russell Mulcahy': ['/name/nm0611683/'],
#  'Pen Densham': ['/name/nm0219720/'],
#  'Luis Buñuel': ['/name/nm0000320/'],
#  'James B. Harris': ['/name/nm0364805/'],
#  'Walerian Borowczyk': ['/name/nm0097259/'],
#  'Robert M. Young': ['/name/nm0950001/'],
#  'Michael Almereyda': ['/name/nm0021899/'],
#  "Jim O'Connolly": ['/name/nm0640226/'],
#  'Chuck Jones': ['/name/nm0005062/'],
#  'Max Ophüls': ['/name/nm0649097/'],
#  'Compton Bennett': ['/name/nm0071682/'],
#  'Tia Brelis': ['/name/nm0107045/'],
#  'Jonathan Kahn': ['/name/nm4990509/'],
#  'Frank Borzage': ['/name/nm0097648/'],
#  'Paul Morrissey': ['/name/nm0607407/'],
#  'Hubert Cornfield': ['/name/nm0180369/'],
#  'Walter Grauman': ['/name/nm0336139/'],
#  'Cornel Wilde': ['/name/nm0664273/'],
#  'Yann Samuell': ['/name/nm1367933/'],
#  'Delbert Mann': ['/name/nm0542720/'],
#  'James Bolton': ['/name/nm0093404/'],
#  'John Flynn': ['/name/nm0283500/'],
#  'Allan Dwan': ['/name/nm0245385/'],
#  'Rowland V. Lee': ['/name/nm0498174/'],
#  'Griff Furst': ['/name/nm0975225/'],
#  'Jonas Åkerlund': ['/name/nm0959774/'],
#  'Chris Fisher': ['/name/nm1084723/'],
#  'Adam Simon': ['/name/nm0800048/'],
#  'John Malkovich': ['/name/nm0000518/'],
#  'Sidney Franklin': ['/name/nm0291548/'],
#  'Anatole Litvak': ['/name/nm0514822/'],
#  'Allen Reisner': ['/name/nm0718467/'],
#  'William F. Claxton': ['/name/nm0165493/'],
#  'Justin Lee': ['/name/nm4899218/'],
#  'Jan Egleson': ['/name/nm0251057/'],
#  'Kevin Billington': ['/name/nm0082543/'],
#  'Karl Freund': ['/name/nm0005713/'],
#  'Steve Carver': ['/name/nm0142587/'],
#  'David Greene': ['/name/nm0338719/'],
#  'Fred F. Sears': ['/name/nm0780764/'],
#  'Stephen Gyllenhaal': ['/name/nm0350455/'],
#  'Leif Tilden': ['/name/nm0863208/'],
#  'Edwin Sherin': ['/name/nm0792309/'],
#  'Ed Bianchi': ['/name/nm0080601/'],
#  'Philip Dunne': ['/name/nm0242897/'],
#  'Michael Bortman': ['/name/nm0097544/'],
#  'Alan Rudolph': ['/name/nm0748928/'],
#  'Mitchell Lichtenstein': ['/name/nm0509033/'],
#  'Trygve Allister Diesen': ['/name/nm0226148/'],
#  'David Price': ['/name/nm0002606/'],
#  'John Farrow': ['/name/nm0268513/'],
#  'Pinchas Perry': ['/name/nm0675257/'],
#  'Bernhard Wicki': ['/name/nm0926919/'],
#  'Bent Hamer': ['/name/nm0357584/'],
#  'Des McAnuff': ['/name/nm0005197/'],
#  'Lamont Johnson': ['/name/nm0425593/'],
#  'Arnold Laven': ['/name/nm0491852/'],
#  'Jean Renoir': ['/name/nm0719756/'],
#  'Jeremy Kagan': ['/name/nm0434571/'],
#  'William Girdler': ['/name/nm0320852/'],
#  'Daniel Petrie': ['/name/nm0677951/'],
#  'Ira Sachs': ['/name/nm0755158/'],
#  'Thomas Jane': ['/name/nm0005048/'],
#  'Dave Fleischer': ['/name/nm0281487/'],
#  'Richard A. Colla': ['/name/nm0171619/'],
#  'Will Mackenzie': ['/name/nm0533414/'],
#  'Mario Van Peebles': ['/name/nm0005522/'],
#  'David Twohy': ['/name/nm0878638/'],
#  'Curtis Bernhardt': ['/name/nm0076779/'],
#  'Peter Sasdy': ['/name/nm0765856/'],
#  "John 'Bud' Cardos": ['/name/nm0004616/'],
#  'Irvin Kershner': ['/name/nm0449984/'],
#  'Vincent McEveety': ['/name/nm0568546/'],
#  'Wesley Ruggles': ['/name/nm0749484/'],
#  'Franc Roddam': ['/name/nm0734466/'],
#  'Tommy Lee Wallace': ['/name/nm0908890/'],
#  'Richard Rich': ['/name/nm0723704/'],
#  'Irwin Winkler': ['/name/nm0005563/'],
#  'Will Finn': ['/name/nm0278181/'],
#  'Anthony Quinn': ['/name/nm0000063/'],
#  'Brian Jun': ['/name/nm0432420/'],
#  'Robert Collector': ['/name/nm0171720/'],
#  'Dan Ireland': ['/name/nm0006959/'],
#  'Menno Meyjes': ['/name/nm0583675/'],
#  'Daryl Duke': ['/name/nm0241174/'],
#  'David Berry': ['/name/nm2523512/'],
#  'Charles Vidor': ['/name/nm0896533/'],
#  'Phillip Borsos': ['/name/nm0097491/'],
#  ...}

# %%
base_url = "https://www.imdb.com"
c = 0
for director in director_link_dict:
    c += 1
    print(c, director)
    director_url = base_url + director_link_dict[director][0]
    director_soup = get_soup(director_url)
    films = director_soup.find('div', id="filmo-head-director").findNext('div')
    
    for film in films:
        movie = film.find('a')
        if type(movie) != int:
            movie_title = movie.text
            movie_link = movie.get('href')
            movie_soup = get_soup(base_url + movie_link)
    
            detail = get_movie_brief(movie_soup)
            director_film_list.append(detail)
# Out:
# 1 Peter Berg
# 2 Wolfgang Petersen
# 3 Tom Hooper
# 4 Thea Sharrock
# 5 Marc Forster
# 6 Alfred Hitchcock
# 7 Andrea Di Stefano
# 8 Brian De Palma
# 9 Bill Condon
# 10 Nick Cassavetes
# 11 P.J. Hogan
# 12 Amy Heckerling
# 13 Tim Burton
# 14 Andrew Adamson
# 15 Michael Mann
# 16 Sharon Maguire
# 17 Kelly Reichardt
# 18 Nicolas Winding Refn
# 19 Taylor Hackford
# 20 Susanne Bier
# 21 Adrian Lyne
# 22 Chris Weitz
# 23 Danny DeVito
# 24 Steve McQueen
# 25 Oliver Stone
# 26 Clint Eastwood
# 27 Angelina Jolie
# 28 Fede Alvarez
# 29 Doug Liman
# 30 Wes Ball
# 31 David Frankel
# 32 Ron Howard
# 33 Edward Norton
# 34 David Lean
# 35 Curtis Hanson
# 36 Robert Stevenson
# 37 Richard Attenborough
# 38 Björn Runge
# 39 Lasse Hallström
# 40 Neil Burger
# 41 Ben Affleck
# 42 Michael Noer
# 43 Nancy Meyers
# 44 Mike Figgis
# 45 Renny Harlin
# 46 Victor Fleming
# 47 Martin Brest
# 48 Randal Kleiser
# 49 Ashley Avis
# 50 Sydney Pollack
# 51 Mel Stuart
# 52 Bernardo Bertolucci
# 53 Rob Marshall
# 54 James Foley
# 55 Stuart Rosenberg
# 56 Tom Tykwer
# 57 Kevin Costner
# 58 Ted Kotcheff
# 59 James Ponsoldt
# 60 Duncan Jones
# 61 William Friedkin
# 62 Joel Schumacher
# 63 Jon Favreau
# 64 John Hillcoat
# 65 Dean DeBlois
# 66 Paul Verhoeven
# 67 Ang Lee
# 68 Gillian Armstrong
# 69 Donovan Marsh
# 70 Nicolas Roeg
# 71 Edward Zwick
# 72 Douglas McGrath
# 73 Alexander Payne
# 74 Luke Greenfield
# 75 Gregory Hoblit
# 76 John Crowley
# 77 Antoine Fuqua
# 78 Todd Haynes
# 79 Sofia Coppola
# 80 Ken Hughes
# 81 Danny Boyle
# 82 Nikolaj Arcel
# 83 Neil Jordan
# 84 Brett Ratner
# 85 Anthony Minghella
# 86 Tomas Alfredson
# 87 Sidney Lumet
# 88 Josh Boone
# 89 Robert Luketic
# 90 Andrew Bergman
# 91 Vince Marcello
# 92 Wes Anderson
# 93 David Leitch
# 94 Stephen Frears
# 95 Tony Scott
# 96 Greg Berlanti
# 97 Paul Greengrass
# 98 Brad Furman
# 99 David Slade
# 100 Quentin Tarantino
# 101 Garry Marshall
# 102 Ronald Neame
# 103 Peter Hewitt
# 104 Bob Clark
# 105 Stephen Sommers
# 106 Brian Duffield
# 107 Andrew Dominik
# 108 Reed Morano
# 109 Lynne Ramsay
# 110 D.J. Caruso
# 111 John Boorman
# 112 Kevin Reynolds
# 113 Paul W.S. Anderson
# 114 Sam Mendes
# 115 Dee Rees
# 116 Thomas Vinterberg
# 117 Marc Munden
# 118 Walter Hill
# 119 Ron Clements
# 120 Anne Fletcher
# 121 Gary Fleder
# 122 Terry Gilliam
# 123 John Huston
# 124 Mike Nichols
# 125 Peter Weir
# 126 Frank Coraci
# 127 Hany Abu-Assad
# 128 Elizabeth Allen Rosenbaum
# 129 William Wyler
# 130 Brad Silberling
# 131 Scott Frank
# 132 Roger Donaldson
# 133 Terrence Malick
# 134 Jack Garfein
# 135 Burr Steers
# 136 Brett Haley
# 137 Justin Chadwick
# 138 Penny Marshall
# 139 Stephen Daldry
# 140 J Blakeson
# 141 Andrew Stanton
# 142 Gregory Wilson
# 143 Gore Verbinski
# 144 Harald Zwart
# 145 Roman Polanski
# 146 Thor Freudenthal
# 147 Brad Peyton
# 148 Robert Mulligan
# 149 Gavin Hood
# 150 Blake Edwards
# 151 Todd Field
# 152 John Sturges
# 153 Adam Shankman
# 154 Luc Besson
# 155 David Koepp
# 156 Paul Michael Glaser
# 157 Zak Hilditch
# 158 Andrew Davis
# 159 Don Siegel
# 160 Frank Miller
# 161 Shawn Levy
# 162 Luke Snellin
# 163 Sebastián Lelio
# 164 Stefen Fangmeier
# 165 Gabor Csupo
# 166 Susan Johnson
# 167 Lone Scherfig
# 168 John Schlesinger
# 169 Michael Apted
# 170 Marcus Nispel
# 171 Mark Herman
# 172 Scott Kalvert
# 173 Matt Reeves
# 174 Richard Donner
# 175 Paul McGuigan
# 176 Chris Miller
# 177 Jason Reitman
# 178 Robert Schwentke
# 179 John Glen
# 180 Spike Jonze
# 181 Paul Dano
# 182 Phillip Noyce
# 183 Kirk Jones
# 184 Randall Wallace
# 185 Giuseppe Capotondi
# 186 Steven Soderbergh
# 187 Barry Jenkins
# 188 Jon S. Baird
# 189 Mel Brooks
# 190 Kimberly Peirce
# 191 George Pal
# 192 Wolfgang Reitherman
# 193 Gilles Paquet-Brenner
# 194 Cecil B. DeMille
# 195 George Roy Hill
# 196 Henry Selick
# 197 Harold Becker
# 198 Alex Proyas
# 199 Cary Joji Fukunaga
# 200 Bille Woodruff
# 201 Garth Jennings
# 202 Alan J. Pakula
# 203 Richard LaGravenese
# 204 David Swift
# 205 Derek Cianfrance
# 206 Florent-Emilio Siri
# 207 Paul King
# 208 Fernando Meirelles
# 209 James Bobin
# 210 Eli Roth
# 211 Barry Levinson
# 212 Mark Waters
# 213 Shane Black
# 214 Franklin J. Schaffner
# 215 Mathew Cullen
# 216 Ramin Bahrani
# 217 Beeban Kidron
# 218 Danis Tanovic
# 219 Chris Buck
# 220 James Franco
# 221 Debra Granik
# 222 Agnieszka Holland
# 223 James Watkins
# 224 George Tillman Jr.
# 225 James Kent
# 226 Charles Martin Smith
# 227 Richard Fleischer
# 228 James Wong
# 229 Ryan Murphy
# 230 Stephen Herek
# 231 Barry Sonnenfeld
# 232 Phil Alden Robinson
# 233 Sam Raimi
# 234 Eric Brevig
# 235 Michael Hoffman
# 236 Michael Anderson
# 237 Andrew Niccol
# 238 Melville Shavelson
# 239 David Cronenberg
# 240 Kaige Chen
# 241 James L. Brooks
# 242 Simon Curtis
# 243 Kevin Kölsch
# 244 Michael Cristofer
# 245 Jonathan Levine
# 246 Ross Katz
# 247 Robert Altman
# 248 Jim Gillespie
# 249 Jeff Baena
# 250 Andy Serkis
# 251 Scott Stewart
# 252 Val Guest
# 253 Gary Trousdale
# 254 Franco Zeffirelli
# 255 Phil Karlson
# 256 Christian Ditter
# 257 Jesse Peretz
# 258 Alan Parker
# 259 Kevin Macdonald
# 260 Richard Eyre
# 261 Henry Joost
# 262 Henry Hathaway
# 263 Joseph L. Mankiewicz
# 264 John Carpenter
# 265 Andy Fickman
# 266 Arthur Hiller
# 267 Peter Bogdanovich
# 268 Robert Benton
# 269 Alexandre Aja
# 270 Ry Russo-Young
# 271 Ken Kwapis
# 272 W.S. Van Dyke
# 273 Richard Linklater
# 274 Peter Tewksbury
# 275 Vincenzo Natali
# 276 Tommy O'Haver
# 277 Ralph Bakshi
# 278 R.J. Cutler
# 279 Chris Noonan
# 280 Jon Avnet
# 281 Frank Marshall
# 282 Stephen Norrington
# 283 Robert Aldrich
# 284 Breck Eisner
# 285 Peter Yates
# 286 Rowan Joffe
# 287 Michael Caton-Jones
# 288 Paul T. Scheuring
# 289 Robert Redford
# 290 Ava DuVernay
# 291 Lee Tamahori
# 292 Roger Avary
# 293 John Frankenheimer
# 294 Alfonso Gomez-Rejon
# 295 Volker Schlöndorff
# 296 Brad Bird
# 297 Timur Bekmambetov
# 298 David Bowers
# 299 William A. Graham
# 300 Scott Hicks
# 301 James Bridges
# 302 Walter Murch
# 303 John Guillermin
# 304 Greg Barker
# 305 Duwayne Dunham
# 306 George Miller
# 307 Daniel Espinosa
# 308 Anna Boden
# 309 Claire McCarthy
# 310 Vincent Ward
# 311 Lewis Teague
# 312 Shana Feste
# 313 Hal Ashby
# 314 Saul Dibb
# 315 Lee Daniels
# 316 Charles Shyer
# 317 Mary Lambert
# 318 Brian Percival
# 319 Henry Koster
# 320 Jane Campion
# 321 James Ivory
# 322 Tim Johnson
# 323 Joseph Ruben
# 324 Mélanie Laurent
# 325 Simon West
# 326 Akiva Goldsman
# 327 Pierre Morel
# 328 Rob Letterman
# 329 Sergei Bodrov
# 330 Roger Christian
# 331 George P. Cosmatos
# 332 Marielle Heller
# 333 Matt Williams
# 334 Rob Cohen
# 335 John Ford
# 336 Carter Smith
# 337 Simon Wells
# 338 Iain Softley
# 339 Brian G. Hutton
# 340 John Madden
# 341 Billy Wilder
# 342 Jack Clayton
# 343 Cédric Jimenez
# 344 Clyde Geronimi
# 345 Stuart Hazeldine
# 346 Gus Van Sant
# 347 Michael Winner
# 348 Babak Anvari
# 349 Vincente Minnelli
# 350 Richard Glatzer
# 351 Robert Moore
# 352 Anton Corbijn
# 353 Brian Helgeland
# 354 Victor Saville
# 355 Wayne Wang
# 356 Peter Webber
# 357 John Singleton
# 358 Philip Kaufman
# 359 Stephen J. Anderson
# 360 Peter Askin
# 361 Michael Ritchie
# 362 Sean Penn
# 363 F. Gary Gray
# 364 Sam Peckinpah
# 365 Raja Gosnell
# 366 Barbet Schroeder
# 367 Andrew Douglas
# 368 Tom Holland
# 369 Spike Lee
# 370 Walter Salles
# 371 Stella Meghie
# 372 Martin Ritt
# 373 David Leveaux
# 374 Rob Minkoff
# 375 Charles Laughton
# 376 Norman Ferguson
# 377 Marek Kanievska
# 378 Robin Swicord
# 379 George Scribner
# 380 Jan de Bont
# 381 Joe Roth
# 382 Betty Thomas
# 383 Ernst Lubitsch
# 384 Audrey Wells
# 385 Harry Hook
# 386 Hugh Wilson
# 387 Jennifer Yuh Nelson
# 388 Ted Berman
# 389 Jake Schreier
# 390 Michael Rymer
# 391 Vic Armstrong
# 392 Miguel Sapochnik
# 393 Gary Sinise
# 394 Lawrence Kasdan
# 395 Fred Zinnemann
# 396 Kevin Pollak
# 397 John Moore
# 398 Ron Maxwell
# 399 Dean Parisot
# 400 Daniel Attias
# 401 Norman Jewison
# 402 Michael Engler
# 403 Vadim Perelman
# 404 Orson Welles
# 405 Dennis Hopper
# 406 Elliott Lester
# 407 Ken Annakin
# 408 Ken Russell
# 409 Clive Barker
# 410 George Stevens
# 411 Mervyn LeRoy
# 412 Tommy Lee Jones
# 413 Peter Hyams
# 414 Robert Rossen
# 415 Paul Weitz
# 416 Julie Anne Robinson
# 417 Tod Williams
# 418 Wash Westmoreland
# 419 Stephen Kay
# 420 Drew Barrymore
# 421 Gregg Araki
# 422 Craig Zobel
# 423 Michael Curtiz
# 424 Scott Cooper
# 425 Carl Franklin
# 426 Gurinder Chadha
# 427 Elia Kazan
# 428 Joan Micklin Silver
# 429 Frank Oz
# 430 J. Lee Thompson
# 431 Richard Brooks
# 432 Brian Henson
# 433 Michael Reeves
# 434 Daniel Barnz
# 435 Barbra Streisand
# 436 Michael Grandage
# 437 Gary Winick
# 438 Howard Hawks
# 439 Bruce Robinson
# 440 George Sluizer
# 441 Otto Preminger
# 442 Ricky Staub
# 443 Joe Alves
# 444 Christian Marquand
# 445 Josef Rusnak
# 446 Bertrand Tavernier
# 447 Jay Russell
# 448 James Whale
# 449 Rouben Mamoulian
# 450 Peter Sollett
# 451 Peter Kosminsky
# 452 Lewis Milestone
# 453 John Curran
# 454 Mimi Leder
# 455 Mark Robson
# 456 Brian DeCubellis
# 457 Michael Sucsy
# 458 Edwin L. Marin
# 459 Susanna White
# 460 Mark Mylod
# 461 Sara Sugarman
# 462 Jeannot Szwarc
# 463 Luis Llosa
# 464 Thomas Bezucha
# 465 Daniel Petrie Jr.
# 466 William A. Wellman
# 467 Barry Alexander Brown
# 468 James Algar
# 469 Sylvio Tabet
# 470 Nora Twomey
# 471 Don Bluth
# 472 Geoffrey Sax
# 473 Ami Canaan Mann
# 474 Clark Johnson
# 475 Ted Post
# 476 Richard Benjamin
# 477 James Wan
# 478 Lucky McKee
# 479 Joseph Kane
# 480 Mira Nair
# 481 Carl Reiner
# 482 Henry Levin
# 483 Andrzej Bartkowiak
# 484 Arthur Penn
# 485 Gil Kenan
# 486 Hossein Amini
# 487 Ubaldo Ragona
# 488 Pella Kagerman
# 489 Mark Pellington
# 490 Tod Browning
# 491 Ewan McGregor
# 492 Stacie Passon
# 493 Bille August
# 494 George Seaton
# 495 William Peter Blatty
# 496 Ulu Grosbard
# 497 Oliver Hirschbiegel
# 498 Ray Enright
# 499 Joe Dante
# 500 Oren Moverman
# 501 John Schultz
# 502 Ralph Nelson
# 503 Boris Sagal
# 504 Tom Vaughan
# 505 Stephen Hopkins
# 506 Johnny Martin
# 507 Jules Bass
# 508 Michael Sarne
# 509 Elliot Silverstein
# 510 Stacy Title
# 511 Kevin Lima
# 512 Dan Wolman
# 513 Sanaa Hamri
# 514 Michael Carreras
# 515 John Hough
# 516 Walter Lang
# 517 Nicholas Ray
# 518 Peter Chelsom
# 519 David Soren
# 520 Meg Ryan
# 521 Miguel Arteta
# 522 Fred Schepisi
# 523 Bretaigne Windust
# 524 Jonathan Mostow
# 525 Byron Haskin
# 526 Jeffrey Bloom
# 527 Michael O. Sajbel
# 528 Charlie Stratton
# 529 Douglas Sirk
# 530 Bharat Nalluri
# 531 Tony Goldwyn
# 532 Bob Rafelson
# 533 Mike Mitchell
# 534 Wim Wenders
# 535 Jennifer Flackett
# 536 Betty Kaplan
# 537 King Vidor
# 538 Scott Waugh
# 539 Derick Martini
# 540 Bryan Forbes
# 541 Richard Lester
# 542 Ed Harris
# 543 Arne Glimcher
# 544 Roland Joffé
# 545 Brian Gibson
# 546 Billy Bob Thornton
# 547 Gina Prince-Bythewood
# 548 Caroline Thompson
# 549 Sidney J. Furie
# 550 Alan Myerson
# 551 Julian Jarrold
# 552 Fraser C. Heston
# 553 Edward Dmytryk
# 554 Jerry Jameson
# 555 Mark L. Lester
# 556 Hideo Nakata
# 557 John G. Avildsen
# 558 Jason Hall
# 559 Mark Rydell
# 560 George C. Wolfe
# 561 Guillaume Canet
# 562 Paul Johansson
# 563 Michael Winterbottom
# 564 David S. Goyer
# 565 Forest Whitaker
# 566 Henry King
# 567 Terry George
# 568 Edgar G. Ulmer
# 569 Morton DaCosta
# 570 Joseph Sargent
# 571 Gregor Jordan
# 572 Carroll Ballard
# 573 Luis Mandoki
# 574 Stanley Kramer
# 575 Shari Springer Berman
# 576 Roger Michell
# 577 Mel Gibson
# 578 Bernard Rose
# 579 Michael Chapman
# 580 Paul Schrader
# 581 Burt Kennedy
# 582 Marlon Brando
# 583 Uli Edel
# 584 Jon Amiel
# 585 Jamie Blanks
# 586 Michael Crichton
# 587 Melanie Mayron
# 588 Scott Teems
# 589 Gordon Parks
# 590 John Stephenson
# 591 William Teitler
# 592 Lance Mungia
# 593 Matt Cimber
# 594 Gregory La Cava
# 595 Jack Smight
# 596 Albert Lewin
# 597 Jacques Tourneur
# 598 Andrew Sipes
# 599 Nicholas Meyer
# 600 Eric D. Howell
# 601 Eric Red
# 602 Sophie Barthes
# 603 George Armitage
# 604 Fritz Lang
# 605 Bronwen Hughes
# 606 L.Q. Jones
# 607 George Sidney
# 608 Alex Pettyfer
# 609 Guy Hamilton
# 610 Stuart Millar
# 611 John Stevenson
# 612 Shainee Gabel
# 613 Hal Needham
# 614 Peter Douglas
# 615 Graham Annable
# 616 Joe Chappelle
# 617 Joy Batchelor
# 618 William Monahan
# 619 Scott Speer
# 620 Hector Babenco
# 621 Jessica Sharzer
# 622 Shekhar Kapur
# 623 Daniel Alfredson
# 624 Richard Thorpe
# 625 Michael Cacoyannis
# 626 John M. Stahl
# 627 Danny Strong
# 628 Michael Cimino
# 629 Mark Steven Johnson
# 630 Victor Salva
# 631 Tony Richardson
# 632 Annette Haywood-Carter
# 633 Donald Cammell
# 634 Wes Craven
# 635 Mathieu Kassovitz
# 636 Bobby Farrelly
# 637 Daniel Schechter
# 638 Joseph M. Newman
# 639 Susan Seidelman
# 640 Frederik Du Chau
# 641 Preston A. Whitmore II
# 642 Nick Love
# 643 Nicholas Hytner
# 644 Dalton Trumbo
# 645 Norman Tokar
# 646 Rebecca Miller
# 647 Robert Z. Leonard
# 648 René Clair
# 649 Donna Deitch
# 650 Geoff Murphy
# 651 Johnny Depp
# 652 Nicole Holofcener
# 653 John Putch
# 654 Scott McGehee
# 655 Sam Fell
# 656 Gary David Goldberg
# 657 Eric Valette
# 658 Howard Franklin
# 659 Katt Shea
# 660 Frank Lloyd
# 661 Jocelyn Moorhouse
# 662 Liev Schreiber
# 663 David R. Ellis
# 664 Charles A. Nichols
# 665 Keith Gordon
# 666 Haifaa Al-Mansour
# 667 Kriv Stenders
# 668 George Sherman
# 669 Stuart Heisler
# 670 Joshua Logan
# 671 Norman Taurog
# 672 Richard Rush
# 673 James Schamus
# 674 Lili Fini Zanuck
# 675 Rod Hardy
# 676 George Cukor
# 677 Bob Gosse
# 678 Stephan Elliott
# 679 Jean Negulesco
# 680 Amy Berg
# 681 Craig Bolotin
# 682 John Irvin
# 683 Steve Barron
# 684 Jefery Levy
# 685 Daniel Mann
# 686 Don Taylor
# 687 Abel Ferrara
# 688 Wil Shriner
# 689 Tay Garnett
# 690 Joe Pytka
# 691 Delmer Daves
# 692 Tom Gries
# 693 Philip Haas
# 694 William Dieterle
# 695 Pamela Romanowsky
# 696 Callie Khouri
# 697 Buzz Kulik
# 698 George A. Romero
# 699 Gary Nelson
# 700 Jack Arnold
# 701 Lewis John Carlino
# 702 Lewis Allen
# 703 Dan Curtis
# 704 Glen Morgan
# 705 Martin Davidson
# 706 Robin Budd
# 707 Peter H. Hunt
# 708 Roger Vadim
# 709 Sam Weisman
# 710 David L. Cunningham
# 711 James Neilson
# 712 Zalman King
# 713 Courtney Solomon
# 714 Louis King
# 715 Reinhard Klooss
# 716 Andrew V. McLaglen
# 717 Laslo Benedek
# 718 Irwin Allen
# 719 Sam Wood
# 720 David Seltzer
# 721 Frank Perry
# 722 Jean-Jacques Annaud
# 723 Fritz Kiersch
# 724 Paul Feig
# 725 Don Roos
# 726 Edward Drake
# 727 Anjelica Huston
# 728 Frank Tuttle
# 729 Oliver Parker
# 730 Harold Ramis
# 731 Michael Mayer
# 732 Stuart Orme
# 733 Ari Folman
# 734 Hy Averback
# 735 Alexandre Espigares
# 736 Martin Rosen
# 737 Philippe Mora
# 738 Rudolph Maté
# 739 Steve Rash
# 740 Burt Reynolds
# 741 Dick Richards
# 742 Pat O'Connor
# 743 Kevin Connor
# 744 Kevin Rodney Sullivan
# 745 Henrik Ruben Genz
# 746 Michael Polish
# 747 Steve Trenbirth
# 748 John D. Hancock
# 749 Bob Spiers
# 750 Allison Anders
# 751 Angel Gracia
# 752 Charles Sturridge
# 753 Jim Mickle
# 754 Stephen C. Apostolof
# 755 David S. Ward
# 756 Kathryn Bigelow
# 757 James Manera
# 758 John Fawcett
# 759 Liliana Cavani
# 760 Dean Semler
# 761 Paul Newman
# 762 Samuel Fuller
# 763 William Tannen
# 764 Neil LaBute
# 765 Anthony Mann
# 766 David Lowell Rich
# 767 George Abbott
# 768 Adriana Trigiani
# 769 Cyrus Nowrasteh
# 770 Michael Wadleigh
# 771 Jules Dassin
# 772 Bert I. Gordon
# 773 Nathan Juran
# 774 Ray Kellogg
# 775 Lewis Gilbert
# 776 André De Toth
# 777 Charles Jarrott
# 778 Zoltan Korda
# 779 Euzhan Palcy
# 780 François Girard
# 781 Herbert Ross
# 782 Earl Bellamy
# 783 Jack Conway
# 784 David M. Rosenthal
# 785 Isabel Coixet
# 786 Paul Wendkos
# 787 John Cromwell
# 788 Brian Gilbert
# 789 Ida Lupino
# 790 Dylan Kidd
# 791 Jay Martin
# 792 Raoul Walsh
# 793 Budd Boetticher
# 794 Marleen Gorris
# 795 Jeremiah S. Chechik
# 796 Antonio Banderas
# 797 Carlo Carlei
# 798 Steve Buscemi
# 799 Robert Montgomery
# 800 Mark Griffiths
# 801 Norman Z. McLeod
# 802 Stanley Donen
# 803 Phil Joanou
# 804 Gene Saks
# 805 Robert Harling
# 806 Emily Young
# 807 Dick Powell
# 808 Clarence Brown
# 809 Oliver Schmitz
# 810 Anand Tucker
# 811 Lindsay Anderson
# 812 Edmund Goulding
# 813 George Marshall
# 814 David Miller
# 815 James Dearden
# 816 H.C. Potter
# 817 Sandra Nettelbeck
# 818 Malcolm Mowbray
# 819 Dwight H. Little
# 820 Mike Mills
# 821 John Milius
# 822 Erle C. Kenton
# 823 Robert Towne
# 824 Patrick Stettner
# 825 Charles Barton
# 826 Joseph Pevney
# 827 Chuck Russell
# 828 István Szabó
# 829 Richard C. Sarafian
# 830 Andrew van den Houten
# 831 Peter Maris
# 832 Christopher Cain
# 833 William Richert
# 834 Rawson Marshall Thurber
# 835 Stephen Milburn Anderson
# 836 Katja von Garnier
# 837 Robert Siodmak
# 838 Terence Davies
# 839 John Byrum
# 840 Brett Leonard
# 841 Gordon Douglas
# 842 Ivan Passer
# 843 John Glenn
# 844 Bob Dolman
# 845 Stanley R. Jaffe
# 846 Helen Hunt
# 847 Chris Eyre
# 848 Jeremiah Zagar
# 849 Bill Forsyth
# 850 Todd Phillips
# 851 Fletcher Markle
# 852 Alexander Mackendrick
# 853 Jack Cardiff
# 854 Philip Harder
# 855 Roy Ward Baker
# 856 Frank D. Gilroy
# 857 Arthur Lubin
# 858 Carl Schenkel
# 859 Lajos Koltai
# 860 Kevin Bacon
# 861 Roger Corman
# 862 Clare Kilner
# 863 Terence Young
# 864 Mel Ferrer
# 865 Burt Lancaster
# 866 Piers Haggard
# 867 Gillies MacKinnon
# 868 Tim Hunter
# 869 Fred M. Wilcox
# 870 John Polson
# 871 Francis Megahy
# 872 William Marshall
# 873 Peter Kassovitz
# 874 Jack Nicholson
# 875 Carol Reed
# 876 Larry Peerce
# 877 Ben Bolt
# 878 John Roberts
# 879 Javier Elorrieta
# 880 Josef von Sternberg
# 881 Corey Allen
# 882 David Gordon Green
# 883 Franco Amurri
# 884 Barry Shear
# 885 Alan Roberts
# 886 James Clavell
# 887 Andrew Black
# 888 Douglas Heyes
# 889 Robert Clouse
# 890 Larry Cohen
# 891 Paul Bogart
# 892 James Goldstone
# 893 Martin Sheen
# 894 Michael Corrente
# 895 Jim Clark
# 896 Peter Ho-Sun Chan
# 897 Leslie Greif
# 898 Rhys Ernst
# 899 Bruce Beresford
# 900 Hampton Fancher
# 901 Willard Huyck
# 902 Peter Medak
# 903 Martha Coolidge
# 904 Frank Tashlin
# 905 Gary Entin
# 906 Edward Bernds
# 907 John Hoffman
# 908 Norman Mailer
# 909 William Beaudine
# 910 Don Chaffey
# 911 Michelle Manning
# 912 Michael Buster
# 913 Russell Mulcahy
# 914 Pen Densham
# 915 Luis Buñuel
# 916 James B. Harris
# 917 Walerian Borowczyk
# 918 Robert M. Young
# 919 Michael Almereyda
# 920 Jim O'Connolly
# 921 Chuck Jones
# 922 Max Ophüls
# 923 Compton Bennett
# 924 Tia Brelis
# 925 Jonathan Kahn
# 926 Frank Borzage
# 927 Paul Morrissey
# 928 Hubert Cornfield
# 929 Walter Grauman
# 930 Cornel Wilde
# 931 Yann Samuell
# 932 Delbert Mann
# 933 James Bolton
# 934 John Flynn
# 935 Allan Dwan
# 936 Rowland V. Lee
# 937 Griff Furst
# 938 Jonas Åkerlund
# 939 Chris Fisher
# 940 Adam Simon
# 941 John Malkovich
# 942 Sidney Franklin
# 943 Anatole Litvak
# 944 Allen Reisner
# 945 William F. Claxton
# 946 Justin Lee
# 947 Jan Egleson
# 948 Kevin Billington
# 949 Karl Freund
# 950 Steve Carver
# 951 David Greene
# 952 Fred F. Sears
# 953 Stephen Gyllenhaal
# 954 Leif Tilden
# 955 Edwin Sherin
# 956 Ed Bianchi
# 957 Philip Dunne
# 958 Michael Bortman
# 959 Alan Rudolph
# 960 Mitchell Lichtenstein
# 961 Trygve Allister Diesen
# 962 David Price
# 963 John Farrow
# 964 Pinchas Perry
# 965 Bernhard Wicki
# 966 Bent Hamer
# 967 Des McAnuff
# 968 Lamont Johnson
# 969 Arnold Laven
# 970 Jean Renoir
# 971 Jeremy Kagan
# 972 William Girdler
# 973 Daniel Petrie
# 974 Ira Sachs
# 975 Thomas Jane
# 976 Dave Fleischer
# 977 Richard A. Colla
# 978 Will Mackenzie
# 979 Mario Van Peebles
# 980 David Twohy
# 981 Curtis Bernhardt
# 982 Peter Sasdy
# 983 John 'Bud' Cardos
# 984 Irvin Kershner
# 985 Vincent McEveety
# 986 Wesley Ruggles
# 987 Franc Roddam
# 988 Tommy Lee Wallace
# 989 Richard Rich
# 990 Irwin Winkler
# 991 Will Finn
# 992 Anthony Quinn
# 993 Brian Jun
# 994 Robert Collector
# 995 Dan Ireland
# 996 Menno Meyjes
# 997 Daryl Duke
# 998 David Berry
# 999 Charles Vidor
# 1000 Phillip Borsos
# 1001 Willard Carroll
# 1002 John Korty
# 1003 Elliott Nugent
# 1004 John N. Smith
# 1005 Todd Verow
# 1006 Tony Bill
# 1007 Steven Schachter
# 1008 Craig R. Baxley
# 1009 Karel Reisz
# 1010 Abraham Polonsky
# 1011 Scott Elliott
# 1012 Ernest R. Dickerson
# 1013 John Alan Simon
# 1014 Sidney Gilliat
# 1015 Amos Poe
# 1016 John Erman
# 1017 George Axelrod
# 1018 Robert Ellis Miller
# 1019 Vincent Sherman
# 1020 William A. Fraker
# 1021 Paul Mayeda Berges
# 1022 Carl Foreman
# 1023 James B. Clark
# 1024 Leonard Nimoy
# 1025 Noel Black
# 1026 Victor Vicas
# 1027 Jeff Kanew
# 1028 George Nichols Jr.
# 1029 Guy Green

# %%
director_df = pd.DataFrame(director_film_list)

# %%
director_df
# Out:
#               director                     title       year  rating      vote  \
# 0         Roger Kumble         After We Collided 2020-10-23     5.0   16469.0
# 1         Roger Kumble          Falling Inn Love 2019-08-29     5.6   15662.0
# 2      I. Marlene King  Pretty Little Liars: The        NaT     7.1    3862.0
# 3          Aaron Korsh                                  NaT     8.5  361371.0
# 4      I. Marlene King                 Famous in        NaT     6.9    5726.0
# ...                ...                       ...        ...     ...       ...
# 32077        Guy Green               The Snorkel 1958-07-07     6.8    1191.0
# 32078        Guy Green          Triple Deception 1956-11-19     6.0     160.0
# 32079        Guy Green           Tears for Simon 1957-01-04     6.4     296.0
# 32080        Guy Green       Postmark for Danger 1956-01-18     6.4     455.0
# 32081        Guy Green                River Beat 1954-07-16     6.2     108.0
#
#                        genre_list    budget   opening  gross_usa    gross_cw  \
# 0                [Drama, Romance]       NaN  422899.0  2386483.0  47990414.0
# 1               [Comedy, Romance]       NaN       NaN        NaN         NaN
# 2         [Crime, Drama, Mystery]       NaN       NaN        NaN         NaN
# 3                 [Comedy, Drama]       NaN       NaN        NaN         NaN
# 4                [Drama, Romance]       NaN       NaN        NaN         NaN
# ...                           ...       ...       ...        ...         ...
# 32077    [Crime, Horror, Mystery]  100000.0       NaN        NaN         NaN
# 32078    [Crime, Drama, Thriller]       NaN       NaN        NaN         NaN
# 32079  [Crime, Mystery, Thriller]       NaN       NaN        NaN         NaN
# 32080     [Crime, Drama, Mystery]       NaN       NaN        NaN         NaN
# 32081              [Crime, Drama]       NaN       NaN        NaN         NaN
#
#        runtime                                             writer  \
# 0        105.0                          [Anna Todd, Mario Celaya]
# 1         98.0                [Elizabeth Hackett, Hilary Galanoy]
# 2         45.0  [Sasha Pieterse, Janel Parrish, Sofia Carson, ...
# 3         44.0  [Gabriel Macht, Patrick J. Adams, Meghan Markl...
# 4         42.0  [Bella Thorne, Charlie DePew, Carter Jenkins, ...
# ...        ...                                                ...
# 32077     90.0                      [Peter Myers, Jimmy Sangster]
# 32078     97.0                    [Sterling Noel, Robert Buckner]
# 32079     89.0                                      [Janet Green]
# 32080     78.0                            [Ken Hughes, Guy Green]
# 32081      NaN                                      [Rex Rienits]
#
#                                                     star  \
# 0      [Josephine Langford, Hero Fiennes Tiffin, Dyla...
# 1      [Christina Milian, Adam Demos, Jeffrey Bowyer-...
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 32077     [Peter van Eyck, Betta St. John, Mandy Miller]
# 32078    [Michael Craig, Julia Arnall, Brenda de Banzie]
# 32079         [David Farrar, David Knight, Julia Arnall]
# 32080    [Robert Beatty, Terry Moore, William Sylvester]
# 32081         [Phyllis Kirk, John Bentley, Robert Ayres]
#
#                        distributor
# 0                         CalMaple
# 1                              NaN
# 2          WarnerHorizonTelevision
# 3                         Hypnotic
# 4                       FarahFilms
# ...                            ...
# 32077  ColumbiaPicturesCorporation
# 32078          TheRankOrganisation
# 32079         SydneyBoxProductions
# 32080                InsigniaFilms
# 32081                InsigniaFilms
#
# [32082 rows x 14 columns]

# %%
# Save the data to pickle file
director_df.to_pickle('../dump/director_data')

# %%
director = 'Roger Kumble'
director_url = base_url + director_link_dict[director][0]
director_soup = get_soup(director_url)
films = director_soup.find('div', id="filmo-head-director").findNext('div')

for film in films:
    movie = film.find('a')
    if type(movie) != int:
        movie_title = movie.text
        movie_link = movie.get('href')
        movie_soup = get_soup(base_url + movie_link)

        detail = get_movie_brief(movie_soup)
        director_film_list.append(detail)

# %%
# Out:
#       director            link_d
# 66  Peter Berg  /name/nm0000916/

# %%
# Out:
# director          Peter Berg
# link_d      /name/nm0000916/
# Name: 66, dtype: object

# %%
director_link.iloc[66:]
# Out:
#                 director            link_d
# 66            Peter Berg  /name/nm0000916/
# 67     Wolfgang Petersen  /name/nm0000583/
# 68            Tom Hooper  /name/nm0393799/
# 69         Thea Sharrock  /name/nm4824763/
# 70          Marc Forster  /name/nm0286975/
# ...                  ...               ...
# 1090          Noel Black  /name/nm0085457/
# 1091        Victor Vicas  /name/nm0895857/
# 1092          Jeff Kanew  /name/nm0437596/
# 1093  George Nichols Jr.  /name/nm0629519/
# 1094           Guy Green  /name/nm0337885/
#
# [1029 rows x 2 columns]

# %%
director_link
# Out:
# {'Peter Berg': ['/name/nm0000916/'],
#  'Wolfgang Petersen': ['/name/nm0000583/'],
#  'Tom Hooper': ['/name/nm0393799/'],
#  'Thea Sharrock': ['/name/nm4824763/'],
#  'Marc Forster': ['/name/nm0286975/'],
#  'Alfred Hitchcock': ['/name/nm0000033/'],
#  'Andrea Di Stefano': ['/name/nm0224331/'],
#  'Brian De Palma': ['/name/nm0000361/'],
#  'Bill Condon': ['/name/nm0174374/'],
#  'Nick Cassavetes': ['/name/nm0001024/'],
#  'P.J. Hogan': ['/name/nm0389591/'],
#  'Amy Heckerling': ['/name/nm0002132/'],
#  'Tim Burton': ['/name/nm0000318/'],
#  'Andrew Adamson': ['/name/nm0011470/'],
#  'Michael Mann': ['/name/nm0000520/'],
#  'Sharon Maguire': ['/name/nm0536632/'],
#  'Kelly Reichardt': ['/name/nm0716980/'],
#  'Nicolas Winding Refn': ['/name/nm0716347/'],
#  'Taylor Hackford': ['/name/nm0000431/'],
#  'Susanne Bier': ['/name/nm0081540/'],
#  'Adrian Lyne': ['/name/nm0001490/'],
#  'Chris Weitz': ['/name/nm0919363/'],
#  'Danny DeVito': ['/name/nm0000362/'],
#  'Steve McQueen': ['/name/nm2588606/'],
#  'Oliver Stone': ['/name/nm0000231/'],
#  'Clint Eastwood': ['/name/nm0000142/'],
#  'Angelina Jolie': ['/name/nm0001401/'],
#  'Fede Alvarez': ['/name/nm1793079/'],
#  'Doug Liman': ['/name/nm0510731/'],
#  'Wes Ball': ['/name/nm1226871/'],
#  'David Frankel': ['/name/nm0291205/'],
#  'Ron Howard': ['/name/nm0000165/'],
#  'Edward Norton': ['/name/nm0001570/'],
#  'David Lean': ['/name/nm0000180/'],
#  'Curtis Hanson': ['/name/nm0000436/'],
#  'Robert Stevenson': ['/name/nm0829038/'],
#  'Richard Attenborough': ['/name/nm0000277/'],
#  'Björn Runge': ['/name/nm0750275/'],
#  'Lasse Hallström': ['/name/nm0002120/'],
#  'Neil Burger': ['/name/nm1139726/'],
#  'Ben Affleck': ['/name/nm0000255/'],
#  'Michael Noer': ['/name/nm1840064/'],
#  'Nancy Meyers': ['/name/nm0583600/'],
#  'Mike Figgis': ['/name/nm0001214/'],
#  'Renny Harlin': ['/name/nm0001317/'],
#  'Victor Fleming': ['/name/nm0281808/'],
#  'Martin Brest': ['/name/nm0000976/'],
#  'Randal Kleiser': ['/name/nm0459170/'],
#  'Ashley Avis': ['/name/nm2382037/'],
#  'Sydney Pollack': ['/name/nm0001628/'],
#  'Mel Stuart': ['/name/nm0835799/'],
#  'Bernardo Bertolucci': ['/name/nm0000934/'],
#  'Rob Marshall': ['/name/nm0551128/'],
#  'James Foley': ['/name/nm0001226/'],
#  'Stuart Rosenberg': ['/name/nm0742341/'],
#  'Tom Tykwer': ['/name/nm0878756/'],
#  'Kevin Costner': ['/name/nm0000126/'],
#  'Ted Kotcheff': ['/name/nm0467646/'],
#  'James Ponsoldt': ['/name/nm1242054/'],
#  'Duncan Jones': ['/name/nm1512910/'],
#  'William Friedkin': ['/name/nm0001243/'],
#  'Joel Schumacher': ['/name/nm0001708/'],
#  'Jon Favreau': ['/name/nm0269463/'],
#  'John Hillcoat': ['/name/nm0384825/'],
#  'Dean DeBlois': ['/name/nm0213450/'],
#  'Paul Verhoeven': ['/name/nm0000682/'],
#  'Ang Lee': ['/name/nm0000487/'],
#  'Gillian Armstrong': ['/name/nm0000788/'],
#  'Donovan Marsh': ['/name/nm1804518/'],
#  'Nicolas Roeg': ['/name/nm0001676/'],
#  'Edward Zwick': ['/name/nm0001880/'],
#  'Douglas McGrath': ['/name/nm0569790/'],
#  'Alexander Payne': ['/name/nm0668247/'],
#  'Luke Greenfield': ['/name/nm0339004/'],
#  'Gregory Hoblit': ['/name/nm0387706/'],
#  'John Crowley': ['/name/nm1259871/'],
#  'Antoine Fuqua': ['/name/nm0298807/'],
#  'Todd Haynes': ['/name/nm0001331/'],
#  'Sofia Coppola': ['/name/nm0001068/'],
#  'Ken Hughes': ['/name/nm0400731/'],
#  'Danny Boyle': ['/name/nm0000965/'],
#  'Nikolaj Arcel': ['/name/nm1064048/'],
#  'Neil Jordan': ['/name/nm0001403/'],
#  'Brett Ratner': ['/name/nm0711840/'],
#  'Anthony Minghella': ['/name/nm0005237/'],
#  'Tomas Alfredson': ['/name/nm0019247/'],
#  'Sidney Lumet': ['/name/nm0001486/'],
#  'Josh Boone': ['/name/nm1837748/'],
#  'Robert Luketic': ['/name/nm0525659/'],
#  'Andrew Bergman': ['/name/nm0000921/'],
#  'Vince Marcello': ['/name/nm1479803/'],
#  'Wes Anderson': ['/name/nm0027572/'],
#  'David Leitch': ['/name/nm0500610/'],
#  'Stephen Frears': ['/name/nm0001241/'],
#  'Tony Scott': ['/name/nm0001716/'],
#  'Greg Berlanti': ['/name/nm0075528/'],
#  'Paul Greengrass': ['/name/nm0339030/'],
#  'Brad Furman': ['/name/nm1026778/'],
#  'David Slade': ['/name/nm1720541/'],
#  'Quentin Tarantino': ['/name/nm0000233/'],
#  'Garry Marshall': ['/name/nm0005190/'],
#  'Ronald Neame': ['/name/nm0623768/'],
#  'Peter Hewitt': ['/name/nm0382072/'],
#  'Bob Clark': ['/name/nm0163706/'],
#  'Stephen Sommers': ['/name/nm0814085/'],
#  'Brian Duffield': ['/name/nm3929259/'],
#  'Andrew Dominik': ['/name/nm0231596/'],
#  'Reed Morano': ['/name/nm1543747/'],
#  'Lynne Ramsay': ['/name/nm0708903/'],
#  'D.J. Caruso': ['/name/nm0142286/'],
#  'John Boorman': ['/name/nm0000958/'],
#  'Kevin Reynolds': ['/name/nm0721817/'],
#  'Paul W.S. Anderson': ['/name/nm0027271/'],
#  'Sam Mendes': ['/name/nm0005222/'],
#  'Dee Rees': ['/name/nm2011696/'],
#  'Thomas Vinterberg': ['/name/nm0899121/'],
#  'Marc Munden': ['/name/nm0612720/'],
#  'Walter Hill': ['/name/nm0001353/'],
#  'Ron Clements': ['/name/nm0166256/'],
#  'Anne Fletcher': ['/name/nm0281945/'],
#  'Gary Fleder': ['/name/nm0001219/'],
#  'Terry Gilliam': ['/name/nm0000416/'],
#  'John Huston': ['/name/nm0001379/'],
#  'Mike Nichols': ['/name/nm0001566/'],
#  'Peter Weir': ['/name/nm0001837/'],
#  'Frank Coraci': ['/name/nm0178997/'],
#  'Hany Abu-Assad': ['/name/nm0009463/'],
#  'Elizabeth Allen Rosenbaum': ['/name/nm0020491/'],
#  'William Wyler': ['/name/nm0943758/'],
#  'Brad Silberling': ['/name/nm0797869/'],
#  'Scott Frank': ['/name/nm0291082/'],
#  'Roger Donaldson': ['/name/nm0002044/'],
#  'Terrence Malick': ['/name/nm0000517/'],
#  'Jack Garfein': ['/name/nm0307246/'],
#  'Burr Steers': ['/name/nm0824882/'],
#  'Brett Haley': ['/name/nm1417640/'],
#  'Justin Chadwick': ['/name/nm0149491/'],
#  'Penny Marshall': ['/name/nm0001508/'],
#  'Stephen Daldry': ['/name/nm0197636/'],
#  'J Blakeson': ['/name/nm2128335/'],
#  'Andrew Stanton': ['/name/nm0004056/'],
#  'Gregory Wilson': ['/name/nm0933471/'],
#  'Gore Verbinski': ['/name/nm0893659/'],
#  'Harald Zwart': ['/name/nm0958969/'],
#  'Roman Polanski': ['/name/nm0000591/'],
#  'Thor Freudenthal': ['/name/nm0294457/'],
#  'Brad Peyton': ['/name/nm0679031/'],
#  'Robert Mulligan': ['/name/nm0612322/'],
#  'Gavin Hood': ['/name/nm0004303/'],
#  'Blake Edwards': ['/name/nm0001175/'],
#  'Todd Field': ['/name/nm0276062/'],
#  'John Sturges': ['/name/nm0836328/'],
#  'Adam Shankman': ['/name/nm0788202/'],
#  'Luc Besson': ['/name/nm0000108/'],
#  'David Koepp': ['/name/nm0462895/'],
#  'Paul Michael Glaser': ['/name/nm0001274/'],
#  'Zak Hilditch': ['/name/nm1991847/'],
#  'Andrew Davis': ['/name/nm0001112/'],
#  'Don Siegel': ['/name/nm0796923/'],
#  'Frank Miller': ['/name/nm0588340/'],
#  'Shawn Levy': ['/name/nm0506613/'],
#  'Luke Snellin': ['/name/nm2866226/'],
#  'Sebastián Lelio': ['/name/nm0133326/'],
#  'Stefen Fangmeier': ['/name/nm0266777/'],
#  'Gabor Csupo': ['/name/nm0190780/'],
#  'Susan Johnson': ['/name/nm0426287/'],
#  'Lone Scherfig': ['/name/nm0771054/'],
#  'John Schlesinger': ['/name/nm0772259/'],
#  'Michael Apted': ['/name/nm0000776/'],
#  'Marcus Nispel': ['/name/nm1197971/'],
#  'Mark Herman': ['/name/nm0379179/'],
#  'Scott Kalvert': ['/name/nm0436284/'],
#  'Matt Reeves': ['/name/nm0716257/'],
#  'Richard Donner': ['/name/nm0001149/'],
#  'Paul McGuigan': ['/name/nm0006476/'],
#  'Chris Miller': ['/name/nm1844237/'],
#  'Jason Reitman': ['/name/nm0718646/'],
#  'Robert Schwentke': ['/name/nm0777881/'],
#  'John Glen': ['/name/nm0322515/'],
#  'Spike Jonze': ['/name/nm0005069/'],
#  'Paul Dano': ['/name/nm0200452/'],
#  'Phillip Noyce': ['/name/nm0637518/'],
#  'Kirk Jones': ['/name/nm0428600/'],
#  'Randall Wallace': ['/name/nm0908824/'],
#  'Giuseppe Capotondi': ['/name/nm3321297/'],
#  'Steven Soderbergh': ['/name/nm0001752/'],
#  'Barry Jenkins': ['/name/nm1503575/'],
#  'Jon S. Baird': ['/name/nm1580671/'],
#  'Mel Brooks': ['/name/nm0000316/'],
#  'Kimberly Peirce': ['/name/nm0005303/'],
#  'George Pal': ['/name/nm0657162/'],
#  'Wolfgang Reitherman': ['/name/nm0718627/'],
#  'Gilles Paquet-Brenner': ['/name/nm0660707/'],
#  'Cecil B. DeMille': ['/name/nm0001124/'],
#  'George Roy Hill': ['/name/nm0001351/'],
#  'Henry Selick': ['/name/nm0783139/'],
#  'Harold Becker': ['/name/nm0000887/'],
#  'Alex Proyas': ['/name/nm0001639/'],
#  'Cary Joji Fukunaga': ['/name/nm1560977/'],
#  'Bille Woodruff': ['/name/nm0937306/'],
#  'Garth Jennings': ['/name/nm1134029/'],
#  'Alan J. Pakula': ['/name/nm0001587/'],
#  'Richard LaGravenese': ['/name/nm0481418/'],
#  'David Swift': ['/name/nm0842582/'],
#  'Derek Cianfrance': ['/name/nm0161834/'],
#  'Florent-Emilio Siri': ['/name/nm0802807/'],
#  'Paul King': ['/name/nm1653753/'],
#  'Fernando Meirelles': ['/name/nm0576987/'],
#  'James Bobin': ['/name/nm0090386/'],
#  'Eli Roth': ['/name/nm0744834/'],
#  'Barry Levinson': ['/name/nm0001469/'],
#  'Mark Waters': ['/name/nm0914132/'],
#  'Shane Black': ['/name/nm0000948/'],
#  'Franklin J. Schaffner': ['/name/nm0769874/'],
#  'Mathew Cullen': ['/name/nm3810122/'],
#  'Ramin Bahrani': ['/name/nm1023919/'],
#  'Beeban Kidron': ['/name/nm0452319/'],
#  'Danis Tanovic': ['/name/nm0849786/'],
#  'Chris Buck': ['/name/nm0118333/'],
#  'James Franco': ['/name/nm0290556/'],
#  'Debra Granik': ['/name/nm0335138/'],
#  'Agnieszka Holland': ['/name/nm0002140/'],
#  'James Watkins': ['/name/nm1220140/'],
#  'George Tillman Jr.': ['/name/nm0863387/'],
#  'James Kent': ['/name/nm0448757/'],
#  'Charles Martin Smith': ['/name/nm0001747/'],
#  'Richard Fleischer': ['/name/nm0281507/'],
#  'James Wong': ['/name/nm0939128/'],
#  'Ryan Murphy': ['/name/nm0614682/'],
#  'Stephen Herek': ['/name/nm0378893/'],
#  'Barry Sonnenfeld': ['/name/nm0001756/'],
#  'Phil Alden Robinson': ['/name/nm0004675/'],
#  'Sam Raimi': ['/name/nm0000600/'],
#  'Eric Brevig': ['/name/nm0108094/'],
#  'Michael Hoffman': ['/name/nm0001355/'],
#  'Michael Anderson': ['/name/nm0027183/'],
#  'Andrew Niccol': ['/name/nm0629272/'],
#  'Melville Shavelson': ['/name/nm0789520/'],
#  'David Cronenberg': ['/name/nm0000343/'],
#  'Kaige Chen': ['/name/nm0155280/'],
#  'James L. Brooks': ['/name/nm0000985/'],
#  'Simon Curtis': ['/name/nm0193508/'],
#  'Kevin Kölsch': ['/name/nm1556116/'],
#  'Michael Cristofer': ['/name/nm0188165/'],
#  'Jonathan Levine': ['/name/nm1349522/'],
#  'Ross Katz': ['/name/nm0441839/'],
#  'Robert Altman': ['/name/nm0000265/'],
#  'Jim Gillespie': ['/name/nm0318947/'],
#  'Jeff Baena': ['/name/nm1337885/'],
#  'Andy Serkis': ['/name/nm0785227/'],
#  'Scott Stewart': ['/name/nm0829820/'],
#  'Val Guest': ['/name/nm0346436/'],
#  'Gary Trousdale': ['/name/nm0873779/'],
#  'Franco Zeffirelli': ['/name/nm0001874/'],
#  'Phil Karlson': ['/name/nm0439597/'],
#  'Christian Ditter': ['/name/nm0228542/'],
#  'Jesse Peretz': ['/name/nm0673400/'],
#  'Alan Parker': ['/name/nm0000570/'],
#  'Kevin Macdonald': ['/name/nm0531817/'],
#  'Richard Eyre': ['/name/nm0264236/'],
#  'Henry Joost': ['/name/nm1160962/'],
#  'Henry Hathaway': ['/name/nm0368871/'],
#  'Joseph L. Mankiewicz': ['/name/nm0000581/'],
#  'John Carpenter': ['/name/nm0000118/'],
#  'Andy Fickman': ['/name/nm0275698/'],
#  'Arthur Hiller': ['/name/nm0002137/'],
#  'Peter Bogdanovich': ['/name/nm0000953/'],
#  'Robert Benton': ['/name/nm0000914/'],
#  'Alexandre Aja': ['/name/nm0014960/'],
#  'Ry Russo-Young': ['/name/nm1735543/'],
#  'Ken Kwapis': ['/name/nm0477129/'],
#  'W.S. Van Dyke': ['/name/nm0886754/'],
#  'Richard Linklater': ['/name/nm0000500/'],
#  'Peter Tewksbury': ['/name/nm0856715/'],
#  'Vincenzo Natali': ['/name/nm0622112/'],
#  "Tommy O'Haver": ['/name/nm0641373/'],
#  'Ralph Bakshi': ['/name/nm0000835/'],
#  'R.J. Cutler': ['/name/nm0191712/'],
#  'Chris Noonan': ['/name/nm0003088/'],
#  'Jon Avnet': ['/name/nm0000816/'],
#  'Frank Marshall': ['/name/nm0550881/'],
#  'Stephen Norrington': ['/name/nm0635759/'],
#  'Robert Aldrich': ['/name/nm0000736/'],
#  'Breck Eisner': ['/name/nm0252135/'],
#  'Peter Yates': ['/name/nm0946811/'],
#  'Rowan Joffe': ['/name/nm0423626/'],
#  'Michael Caton-Jones': ['/name/nm0001994/'],
#  'Paul T. Scheuring': ['/name/nm0771228/'],
#  'Robert Redford': ['/name/nm0000602/'],
#  'Ava DuVernay': ['/name/nm1148550/'],
#  'Lee Tamahori': ['/name/nm0848414/'],
#  'Roger Avary': ['/name/nm0000812/'],
#  'John Frankenheimer': ['/name/nm0001239/'],
#  'Alfonso Gomez-Rejon': ['/name/nm0004234/'],
#  'Volker Schlöndorff': ['/name/nm0772522/'],
#  'Brad Bird': ['/name/nm0083348/'],
#  'Timur Bekmambetov': ['/name/nm0067457/'],
#  'David Bowers': ['/name/nm0101047/'],
#  'William A. Graham': ['/name/nm0334353/'],
#  'Scott Hicks': ['/name/nm0382956/'],
#  'James Bridges': ['/name/nm0108745/'],
#  'Walter Murch': ['/name/nm0004555/'],
#  'John Guillermin': ['/name/nm0347086/'],
#  'Greg Barker': ['/name/nm0994499/'],
#  'Duwayne Dunham': ['/name/nm0242271/'],
#  'George Miller': ['/name/nm0004306/'],
#  'Daniel Espinosa': ['/name/nm1174251/'],
#  'Anna Boden': ['/name/nm1349818/'],
#  'Claire McCarthy': ['/name/nm2113122/'],
#  'Vincent Ward': ['/name/nm0911910/'],
#  'Lewis Teague': ['/name/nm0853546/'],
#  'Shana Feste': ['/name/nm0275277/'],
#  'Hal Ashby': ['/name/nm0000797/'],
#  'Saul Dibb': ['/name/nm1314116/'],
#  'Lee Daniels': ['/name/nm0200005/'],
#  'Charles Shyer': ['/name/nm0796124/'],
#  'Mary Lambert': ['/name/nm0005116/'],
#  'Brian Percival': ['/name/nm1093053/'],
#  'Henry Koster': ['/name/nm0467396/'],
#  'Jane Campion': ['/name/nm0001005/'],
#  'James Ivory': ['/name/nm0412465/'],
#  'Tim Johnson': ['/name/nm0426333/'],
#  'Joseph Ruben': ['/name/nm0747849/'],
#  'Mélanie Laurent': ['/name/nm0491259/'],
#  'Simon West': ['/name/nm0922346/'],
#  'Akiva Goldsman': ['/name/nm0326040/'],
#  'Pierre Morel': ['/name/nm0603628/'],
#  'Rob Letterman': ['/name/nm1224299/'],
#  'Sergei Bodrov': ['/name/nm0091076/'],
#  'Roger Christian': ['/name/nm0002337/'],
#  'George P. Cosmatos': ['/name/nm0181902/'],
#  'Marielle Heller': ['/name/nm1716636/'],
#  'Matt Williams': ['/name/nm0931285/'],
#  'Rob Cohen': ['/name/nm0003418/'],
#  'John Ford': ['/name/nm0000406/'],
#  'Carter Smith': ['/name/nm2127650/'],
#  'Simon Wells': ['/name/nm0920425/'],
#  'Iain Softley': ['/name/nm0812200/'],
#  'Brian G. Hutton': ['/name/nm0404606/'],
#  'John Madden': ['/name/nm0006960/'],
#  'Billy Wilder': ['/name/nm0000697/'],
#  'Jack Clayton': ['/name/nm0002338/'],
#  'Cédric Jimenez': ['/name/nm1473428/'],
#  'Clyde Geronimi': ['/name/nm0314671/'],
#  'Stuart Hazeldine': ['/name/nm0371955/'],
#  'Gus Van Sant': ['/name/nm0001814/'],
#  'Michael Winner': ['/name/nm0935382/'],
#  'Babak Anvari': ['/name/nm2035118/'],
#  'Vincente Minnelli': ['/name/nm0591486/'],
#  'Richard Glatzer': ['/name/nm0322144/'],
#  'Robert Moore': ['/name/nm0601800/'],
#  'Anton Corbijn': ['/name/nm0179221/'],
#  'Brian Helgeland': ['/name/nm0001338/'],
#  'Victor Saville': ['/name/nm0767701/'],
#  'Wayne Wang': ['/name/nm0911061/'],
#  'Peter Webber': ['/name/nm0916424/'],
#  'John Singleton': ['/name/nm0005436/'],
#  'Philip Kaufman': ['/name/nm0442241/'],
#  'Stephen J. Anderson': ['/name/nm0027459/'],
#  'Peter Askin': ['/name/nm0039468/'],
#  'Michael Ritchie': ['/name/nm0006916/'],
#  'Sean Penn': ['/name/nm0000576/'],
#  'F. Gary Gray': ['/name/nm0336620/'],
#  'Sam Peckinpah': ['/name/nm0001603/'],
#  'Raja Gosnell': ['/name/nm0331532/'],
#  'Barbet Schroeder': ['/name/nm0775447/'],
#  'Andrew Douglas': ['/name/nm1497918/'],
#  'Tom Holland': ['/name/nm0276169/'],
#  'Spike Lee': ['/name/nm0000490/'],
#  'Walter Salles': ['/name/nm0758574/'],
#  'Stella Meghie': ['/name/nm4907810/'],
#  'Martin Ritt': ['/name/nm0728688/'],
#  'David Leveaux': ['/name/nm1659505/'],
#  'Rob Minkoff': ['/name/nm0591450/'],
#  'Charles Laughton': ['/name/nm0001452/'],
#  'Norman Ferguson': ['/name/nm0272568/'],
#  'Marek Kanievska': ['/name/nm0437709/'],
#  'Robin Swicord': ['/name/nm0842523/'],
#  'George Scribner': ['/name/nm0780117/'],
#  'Jan de Bont': ['/name/nm0000957/'],
#  'Joe Roth': ['/name/nm0005387/'],
#  'Betty Thomas': ['/name/nm0858525/'],
#  'Ernst Lubitsch': ['/name/nm0523932/'],
#  'Audrey Wells': ['/name/nm0920108/'],
#  'Harry Hook': ['/name/nm0393591/'],
#  'Hugh Wilson': ['/name/nm0933505/'],
#  'Jennifer Yuh Nelson': ['/name/nm0950775/'],
#  'Ted Berman': ['/name/nm0075859/'],
#  'Jake Schreier': ['/name/nm1500577/'],
#  'Michael Rymer': ['/name/nm0753382/'],
#  'Vic Armstrong': ['/name/nm0002184/'],
#  'Miguel Sapochnik': ['/name/nm0764601/'],
#  'Gary Sinise': ['/name/nm0000641/'],
#  'Lawrence Kasdan': ['/name/nm0001410/'],
#  'Fred Zinnemann': ['/name/nm0003593/'],
#  'Kevin Pollak': ['/name/nm0001629/'],
#  'John Moore': ['/name/nm0601382/'],
#  'Ron Maxwell': ['/name/nm0561813/'],
#  'Dean Parisot': ['/name/nm0661751/'],
#  'Daniel Attias': ['/name/nm0003733/'],
#  'Norman Jewison': ['/name/nm0422484/'],
#  'Michael Engler': ['/name/nm0257554/'],
#  'Vadim Perelman': ['/name/nm1166926/'],
#  'Orson Welles': ['/name/nm0000080/'],
#  'Dennis Hopper': ['/name/nm0000454/'],
#  'Elliott Lester': ['/name/nm1714255/'],
#  'Ken Annakin': ['/name/nm0002175/'],
#  'Ken Russell': ['/name/nm0001692/'],
#  'Clive Barker': ['/name/nm0000850/'],
#  'George Stevens': ['/name/nm0828419/'],
#  'Mervyn LeRoy': ['/name/nm0503777/'],
#  'Tommy Lee Jones': ['/name/nm0000169/'],
#  'Peter Hyams': ['/name/nm0001382/'],
#  'Robert Rossen': ['/name/nm0744035/'],
#  'Paul Weitz': ['/name/nm0919369/'],
#  'Julie Anne Robinson': ['/name/nm1455688/'],
#  'Tod Williams': ['/name/nm0931095/'],
#  'Wash Westmoreland': ['/name/nm0922903/'],
#  'Stephen Kay': ['/name/nm0443181/'],
#  'Drew Barrymore': ['/name/nm0000106/'],
#  'Gregg Araki': ['/name/nm0000777/'],
#  'Craig Zobel': ['/name/nm0957505/'],
#  'Michael Curtiz': ['/name/nm0002031/'],
#  'Scott Cooper': ['/name/nm0178376/'],
#  'Carl Franklin': ['/name/nm0002083/'],
#  'Gurinder Chadha': ['/name/nm0149446/'],
#  'Elia Kazan': ['/name/nm0001415/'],
#  'Joan Micklin Silver': ['/name/nm0798717/'],
#  'Frank Oz': ['/name/nm0000568/'],
#  'J. Lee Thompson': ['/name/nm0496746/'],
#  'Richard Brooks': ['/name/nm0112218/'],
#  'Brian Henson': ['/name/nm0005008/'],
#  'Michael Reeves': ['/name/nm0716262/'],
#  'Daniel Barnz': ['/name/nm1400426/'],
#  'Barbra Streisand': ['/name/nm0000659/'],
#  'Michael Grandage': ['/name/nm0334787/'],
#  'Gary Winick': ['/name/nm0935095/'],
#  'Howard Hawks': ['/name/nm0001328/'],
#  'Bruce Robinson': ['/name/nm0732430/'],
#  'George Sluizer': ['/name/nm0806293/'],
#  'Otto Preminger': ['/name/nm0695937/'],
#  'Ricky Staub': ['/name/nm2598995/'],
#  'Joe Alves': ['/name/nm0023469/'],
#  'Christian Marquand': ['/name/nm0549650/'],
#  'Josef Rusnak': ['/name/nm0750857/'],
#  'Bertrand Tavernier': ['/name/nm0851724/'],
#  'Jay Russell': ['/name/nm0751221/'],
#  'James Whale': ['/name/nm0001843/'],
#  'Rouben Mamoulian': ['/name/nm0541149/'],
#  'Peter Sollett': ['/name/nm0813164/'],
#  'Peter Kosminsky': ['/name/nm0467225/'],
#  'Lewis Milestone': ['/name/nm0587277/'],
#  'John Curran': ['/name/nm0192845/'],
#  'Mimi Leder': ['/name/nm0001460/'],
#  'Mark Robson': ['/name/nm0733476/'],
#  'Brian DeCubellis': ['/name/nm1802093/'],
#  'Michael Sucsy': ['/name/nm1302591/'],
#  'Edwin L. Marin': ['/name/nm0547446/'],
#  'Susanna White': ['/name/nm1264352/'],
#  'Mark Mylod': ['/name/nm0617042/'],
#  'Sara Sugarman': ['/name/nm0837406/'],
#  'Jeannot Szwarc': ['/name/nm0844358/'],
#  'Luis Llosa': ['/name/nm0515891/'],
#  'Thomas Bezucha': ['/name/nm0080120/'],
#  'Daniel Petrie Jr.': ['/name/nm0677943/'],
#  'William A. Wellman': ['/name/nm0920074/'],
#  'Barry Alexander Brown': ['/name/nm0113084/'],
#  'James Algar': ['/name/nm0019282/'],
#  'Sylvio Tabet': ['/name/nm0845973/'],
#  'Nora Twomey': ['/name/nm1316072/'],
#  'Don Bluth': ['/name/nm0089940/'],
#  'Geoffrey Sax': ['/name/nm0768249/'],
#  'Ami Canaan Mann': ['/name/nm0542642/'],
#  'Clark Johnson': ['/name/nm0424800/'],
#  'Ted Post': ['/name/nm0692872/'],
#  'Richard Benjamin': ['/name/nm0000907/'],
#  'James Wan': ['/name/nm1490123/'],
#  'Lucky McKee': ['/name/nm1031246/'],
#  'Joseph Kane': ['/name/nm0437356/'],
#  'Mira Nair': ['/name/nm0619762/'],
#  'Carl Reiner': ['/name/nm0005348/'],
#  'Henry Levin': ['/name/nm0505610/'],
#  'Andrzej Bartkowiak': ['/name/nm0005647/'],
#  'Arthur Penn': ['/name/nm0671957/'],
#  'Gil Kenan': ['/name/nm1481493/'],
#  'Hossein Amini': ['/name/nm0024925/'],
#  'Ubaldo Ragona': ['/name/nm0706575/'],
#  'Pella Kagerman': ['/name/nm2445423/'],
#  'Mark Pellington': ['/name/nm0671210/'],
#  'Tod Browning': ['/name/nm0115218/'],
#  'Ewan McGregor': ['/name/nm0000191/'],
#  'Stacie Passon': ['/name/nm4945419/'],
#  'Bille August': ['/name/nm0000806/'],
#  'George Seaton': ['/name/nm0780833/'],
#  'William Peter Blatty': ['/name/nm0087861/'],
#  'Ulu Grosbard': ['/name/nm0343260/'],
#  'Oliver Hirschbiegel': ['/name/nm0386570/'],
#  'Ray Enright': ['/name/nm0258015/'],
#  'Joe Dante': ['/name/nm0001102/'],
#  'Oren Moverman': ['/name/nm0610219/'],
#  'John Schultz': ['/name/nm0776271/'],
#  'Ralph Nelson': ['/name/nm0625680/'],
#  'Boris Sagal': ['/name/nm0755963/'],
#  'Tom Vaughan': ['/name/nm0891114/'],
#  'Stephen Hopkins': ['/name/nm0394280/'],
#  'Johnny Martin': ['/name/nm0552565/'],
#  'Jules Bass': ['/name/nm0060072/'],
#  'Michael Sarne': ['/name/nm0765398/'],
#  'Elliot Silverstein': ['/name/nm0799033/'],
#  'Stacy Title': ['/name/nm0864468/'],
#  'Kevin Lima': ['/name/nm0510674/'],
#  'Dan Wolman': ['/name/nm0938630/'],
#  'Sanaa Hamri': ['/name/nm1065402/'],
#  'Michael Carreras': ['/name/nm0140257/'],
#  'John Hough': ['/name/nm0396421/'],
#  'Walter Lang': ['/name/nm0485943/'],
#  'Nicholas Ray': ['/name/nm0712947/'],
#  'Peter Chelsom': ['/name/nm0155093/'],
#  'David Soren': ['/name/nm1659741/'],
#  'Meg Ryan': ['/name/nm0000212/'],
#  'Miguel Arteta': ['/name/nm0037708/'],
#  'Fred Schepisi': ['/name/nm0770961/'],
#  'Bretaigne Windust': ['/name/nm0934827/'],
#  'Jonathan Mostow': ['/name/nm0609236/'],
#  'Byron Haskin': ['/name/nm0005738/'],
#  'Jeffrey Bloom': ['/name/nm0089177/'],
#  'Michael O. Sajbel': ['/name/nm0756935/'],
#  'Charlie Stratton': ['/name/nm0771613/'],
#  'Douglas Sirk': ['/name/nm0802862/'],
#  'Bharat Nalluri': ['/name/nm0620576/'],
#  'Tony Goldwyn': ['/name/nm0001282/'],
#  'Bob Rafelson': ['/name/nm0706182/'],
#  'Mike Mitchell': ['/name/nm0593610/'],
#  'Wim Wenders': ['/name/nm0000694/'],
#  'Jennifer Flackett': ['/name/nm0280814/'],
#  'Betty Kaplan': ['/name/nm0438201/'],
#  'King Vidor': ['/name/nm0896542/'],
#  'Scott Waugh': ['/name/nm0915304/'],
#  'Derick Martini': ['/name/nm0553796/'],
#  'Bryan Forbes': ['/name/nm0285302/'],
#  'Richard Lester': ['/name/nm0504513/'],
#  'Ed Harris': ['/name/nm0000438/'],
#  'Arne Glimcher': ['/name/nm0322865/'],
#  'Roland Joffé': ['/name/nm0423646/'],
#  'Brian Gibson': ['/name/nm0001270/'],
#  'Billy Bob Thornton': ['/name/nm0000671/'],
#  'Gina Prince-Bythewood': ['/name/nm0697656/'],
#  'Caroline Thompson': ['/name/nm0003031/'],
#  'Sidney J. Furie': ['/name/nm0002089/'],
#  'Alan Myerson': ['/name/nm0002887/'],
#  'Julian Jarrold': ['/name/nm0418982/'],
#  'Fraser C. Heston': ['/name/nm0381699/'],
#  'Edward Dmytryk': ['/name/nm0229424/'],
#  'Jerry Jameson': ['/name/nm0417054/'],
#  'Mark L. Lester': ['/name/nm0504495/'],
#  'Hideo Nakata': ['/name/nm0620378/'],
#  'John G. Avildsen': ['/name/nm0000814/'],
#  'Jason Hall': ['/name/nm0355699/'],
#  'Mark Rydell': ['/name/nm0041932/'],
#  'George C. Wolfe': ['/name/nm0938045/'],
#  'Guillaume Canet': ['/name/nm0133899/'],
#  'Paul Johansson': ['/name/nm0424035/'],
#  'Michael Winterbottom': ['/name/nm0935863/'],
#  'David S. Goyer': ['/name/nm0275286/'],
#  'Forest Whitaker': ['/name/nm0001845/'],
#  'Henry King': ['/name/nm0454771/'],
#  'Terry George': ['/name/nm0313623/'],
#  'Edgar G. Ulmer': ['/name/nm0880618/'],
#  'Morton DaCosta': ['/name/nm0196536/'],
#  'Joseph Sargent': ['/name/nm0765121/'],
#  'Gregor Jordan': ['/name/nm0429964/'],
#  'Carroll Ballard': ['/name/nm0050597/'],
#  'Luis Mandoki': ['/name/nm0001502/'],
#  'Stanley Kramer': ['/name/nm0006452/'],
#  'Shari Springer Berman': ['/name/nm0075849/'],
#  'Roger Michell': ['/name/nm0585011/'],
#  'Mel Gibson': ['/name/nm0000154/'],
#  'Bernard Rose': ['/name/nm0741262/'],
#  'Michael Chapman': ['/name/nm0152469/'],
#  'Paul Schrader': ['/name/nm0001707/'],
#  'Burt Kennedy': ['/name/nm0447944/'],
#  'Marlon Brando': ['/name/nm0000008/'],
#  'Uli Edel': ['/name/nm0248942/'],
#  'Jon Amiel': ['/name/nm0000750/'],
#  'Jamie Blanks': ['/name/nm0087595/'],
#  'Michael Crichton': ['/name/nm0000341/'],
#  'Melanie Mayron': ['/name/nm0563039/'],
#  'Scott Teems': ['/name/nm1802374/'],
#  'Gordon Parks': ['/name/nm0662953/'],
#  'John Stephenson': ['/name/nm0827268/'],
#  'William Teitler': ['/name/nm0854074/'],
#  'Lance Mungia': ['/name/nm0612812/'],
#  'Matt Cimber': ['/name/nm0162343/'],
#  'Gregory La Cava': ['/name/nm0478441/'],
#  'Jack Smight': ['/name/nm0806915/'],
#  'Albert Lewin': ['/name/nm0506797/'],
#  'Jacques Tourneur': ['/name/nm0869664/'],
#  'Andrew Sipes': ['/name/nm0802617/'],
#  'Nicholas Meyer': ['/name/nm0583292/'],
#  'Eric D. Howell': ['/name/nm0397970/'],
#  'Eric Red': ['/name/nm0714599/'],
#  'Sophie Barthes': ['/name/nm1754436/'],
#  'George Armitage': ['/name/nm0000786/'],
#  'Fritz Lang': ['/name/nm0000485/'],
#  'Bronwen Hughes': ['/name/nm0400486/'],
#  'L.Q. Jones': ['/name/nm0428618/'],
#  'George Sidney': ['/name/nm0796645/'],
#  'Alex Pettyfer': ['/name/nm1641117/'],
#  'Guy Hamilton': ['/name/nm0357891/'],
#  'Stuart Millar': ['/name/nm0587706/'],
#  'John Stevenson': ['/name/nm0828970/'],
#  'Shainee Gabel': ['/name/nm0300015/'],
#  'Hal Needham': ['/name/nm0624102/'],
#  'Peter Douglas': ['/name/nm0235209/'],
#  'Graham Annable': ['/name/nm0030253/'],
#  'Joe Chappelle': ['/name/nm0152640/'],
#  'Joy Batchelor': ['/name/nm0060742/'],
#  'William Monahan': ['/name/nm1184258/'],
#  'Scott Speer': ['/name/nm1228976/'],
#  'Hector Babenco': ['/name/nm0002199/'],
#  'Jessica Sharzer': ['/name/nm0789366/'],
#  'Shekhar Kapur': ['/name/nm0001408/'],
#  'Daniel Alfredson': ['/name/nm0019242/'],
#  'Richard Thorpe': ['/name/nm0861703/'],
#  'Michael Cacoyannis': ['/name/nm0128050/'],
#  'John M. Stahl': ['/name/nm0821472/'],
#  'Danny Strong': ['/name/nm0834960/'],
#  'Michael Cimino': ['/name/nm0001047/'],
#  'Mark Steven Johnson': ['/name/nm0425756/'],
#  'Victor Salva': ['/name/nm0759207/'],
#  'Tony Richardson': ['/name/nm0724798/'],
#  'Annette Haywood-Carter': ['/name/nm0371852/'],
#  'Donald Cammell': ['/name/nm0131910/'],
#  'Wes Craven': ['/name/nm0000127/'],
#  'Mathieu Kassovitz': ['/name/nm0440913/'],
#  'Bobby Farrelly': ['/name/nm0125803/'],
#  'Daniel Schechter': ['/name/nm1633080/'],
#  'Joseph M. Newman': ['/name/nm0628149/'],
#  'Susan Seidelman': ['/name/nm0782384/'],
#  'Frederik Du Chau': ['/name/nm0238865/'],
#  'Preston A. Whitmore II': ['/name/nm0926211/'],
#  'Nick Love': ['/name/nm0522393/'],
#  'Nicholas Hytner': ['/name/nm0405336/'],
#  'Dalton Trumbo': ['/name/nm0874308/'],
#  'Norman Tokar': ['/name/nm0865709/'],
#  'Rebecca Miller': ['/name/nm0589182/'],
#  'Robert Z. Leonard': ['/name/nm0502752/'],
#  'René Clair': ['/name/nm0163229/'],
#  'Donna Deitch': ['/name/nm0215123/'],
#  'Geoff Murphy': ['/name/nm0614276/'],
#  'Johnny Depp': ['/name/nm0000136/'],
#  'Nicole Holofcener': ['/name/nm0392237/'],
#  'John Putch': ['/name/nm0003289/'],
#  'Scott McGehee': ['/name/nm0569166/'],
#  'Sam Fell': ['/name/nm0271402/'],
#  'Gary David Goldberg': ['/name/nm0325204/'],
#  'Eric Valette': ['/name/nm0884659/'],
#  'Howard Franklin': ['/name/nm0291442/'],
#  'Katt Shea': ['/name/nm0002240/'],
#  'Frank Lloyd': ['/name/nm0515979/'],
#  'Jocelyn Moorhouse': ['/name/nm0602104/'],
#  'Liev Schreiber': ['/name/nm0000630/'],
#  'David R. Ellis': ['/name/nm0254786/'],
#  'Charles A. Nichols': ['/name/nm0629363/'],
#  'Keith Gordon': ['/name/nm0330360/'],
#  'Haifaa Al-Mansour': ['/name/nm2223783/'],
#  'Kriv Stenders': ['/name/nm0826541/'],
#  'George Sherman': ['/name/nm0792450/'],
#  'Stuart Heisler': ['/name/nm0374702/'],
#  'Joshua Logan': ['/name/nm0517597/'],
#  'Norman Taurog': ['/name/nm0851537/'],
#  'Richard Rush': ['/name/nm0750701/'],
#  'James Schamus': ['/name/nm0770005/'],
#  'Lili Fini Zanuck': ['/name/nm0005572/'],
#  'Rod Hardy': ['/name/nm0362738/'],
#  'George Cukor': ['/name/nm0002030/'],
#  'Bob Gosse': ['/name/nm0331606/'],
#  'Stephan Elliott': ['/name/nm0254632/'],
#  'Jean Negulesco': ['/name/nm0624535/'],
#  'Amy Berg': ['/name/nm1332844/'],
#  'Craig Bolotin': ['/name/nm0093271/'],
#  'John Irvin': ['/name/nm0410139/'],
#  'Steve Barron': ['/name/nm0006625/'],
#  'Jefery Levy': ['/name/nm0506461/'],
#  'Daniel Mann': ['/name/nm0542702/'],
#  'Don Taylor': ['/name/nm0852279/'],
#  'Abel Ferrara': ['/name/nm0001206/'],
#  'Wil Shriner': ['/name/nm0795407/'],
#  'Tay Garnett': ['/name/nm0307819/'],
#  'Joe Pytka': ['/name/nm0701592/'],
#  'Delmer Daves': ['/name/nm0202681/'],
#  'Tom Gries': ['/name/nm0340981/'],
#  'Philip Haas': ['/name/nm0351993/'],
#  'William Dieterle': ['/name/nm0226189/'],
#  'Pamela Romanowsky': ['/name/nm2408871/'],
#  'Callie Khouri': ['/name/nm0451884/'],
#  'Buzz Kulik': ['/name/nm0474539/'],
#  'George A. Romero': ['/name/nm0001681/'],
#  'Gary Nelson': ['/name/nm0625379/'],
#  'Jack Arnold': ['/name/nm0000791/'],
#  'Lewis John Carlino': ['/name/nm0137573/'],
#  'Lewis Allen': ['/name/nm0020765/'],
#  'Dan Curtis': ['/name/nm0193303/'],
#  'Glen Morgan': ['/name/nm0604688/'],
#  'Martin Davidson': ['/name/nm0203429/'],
#  'Robin Budd': ['/name/nm1180460/'],
#  'Peter H. Hunt': ['/name/nm0402596/'],
#  'Roger Vadim': ['/name/nm0671862/'],
#  'Sam Weisman': ['/name/nm0918873/'],
#  'David L. Cunningham': ['/name/nm0192289/'],
#  'James Neilson': ['/name/nm0624809/'],
#  'Zalman King': ['/name/nm0455394/'],
#  'Courtney Solomon': ['/name/nm0813309/'],
#  'Louis King': ['/name/nm0003422/'],
#  'Reinhard Klooss': ['/name/nm0459996/'],
#  'Andrew V. McLaglen': ['/name/nm0572132/'],
#  'Laslo Benedek': ['/name/nm0070670/'],
#  'Irwin Allen': ['/name/nm0000740/'],
#  'Sam Wood': ['/name/nm0939992/'],
#  'David Seltzer': ['/name/nm0783544/'],
#  'Frank Perry': ['/name/nm0675068/'],
#  'Jean-Jacques Annaud': ['/name/nm0000269/'],
#  'Fritz Kiersch': ['/name/nm0452607/'],
#  'Paul Feig': ['/name/nm0082450/'],
#  'Don Roos': ['/name/nm0740400/'],
#  'Edward Drake': ['/name/nm4864836/'],
#  'Anjelica Huston': ['/name/nm0001378/'],
#  'Frank Tuttle': ['/name/nm0878338/'],
#  'Oliver Parker': ['/name/nm0662529/'],
#  'Harold Ramis': ['/name/nm0000601/'],
#  'Michael Mayer': ['/name/nm1555287/'],
#  'Stuart Orme': ['/name/nm0650233/'],
#  'Ari Folman': ['/name/nm0284369/'],
#  'Hy Averback': ['/name/nm0002195/'],
#  'Alexandre Espigares': ['/name/nm3115348/'],
#  'Martin Rosen': ['/name/nm0742034/'],
#  'Philippe Mora': ['/name/nm0602333/'],
#  'Rudolph Maté': ['/name/nm0005789/'],
#  'Steve Rash': ['/name/nm0711114/'],
#  'Burt Reynolds': ['/name/nm0000608/'],
#  'Dick Richards': ['/name/nm0724059/'],
#  "Pat O'Connor": ['/name/nm0640466/'],
#  'Kevin Connor': ['/name/nm0175428/'],
#  'Kevin Rodney Sullivan': ['/name/nm0838198/'],
#  'Henrik Ruben Genz': ['/name/nm0313227/'],
#  'Michael Polish': ['/name/nm0689187/'],
#  'Steve Trenbirth': ['/name/nm0872045/'],
#  'John D. Hancock': ['/name/nm0359386/'],
#  'Bob Spiers': ['/name/nm0818639/'],
#  'Allison Anders': ['/name/nm0025978/'],
#  'Angel Gracia': ['/name/nm0333471/'],
#  'Charles Sturridge': ['/name/nm0836430/'],
#  'Jim Mickle': ['/name/nm0585344/'],
#  'Stephen C. Apostolof': ['/name/nm0032154/'],
#  'David S. Ward': ['/name/nm0911486/'],
#  'Kathryn Bigelow': ['/name/nm0000941/'],
#  'James Manera': ['/name/nm2690726/'],
#  'John Fawcett': ['/name/nm0269502/'],
#  'Liliana Cavani': ['/name/nm0146960/'],
#  'Dean Semler': ['/name/nm0005871/'],
#  'Paul Newman': ['/name/nm0000056/'],
#  'Samuel Fuller': ['/name/nm0002087/'],
#  'William Tannen': ['/name/nm0849587/'],
#  'Neil LaBute': ['/name/nm0001438/'],
#  'Anthony Mann': ['/name/nm0542649/'],
#  'David Lowell Rich': ['/name/nm0723629/'],
#  'George Abbott': ['/name/nm0007973/'],
#  'Adriana Trigiani': ['/name/nm0872765/'],
#  'Cyrus Nowrasteh': ['/name/nm0637493/'],
#  'Michael Wadleigh': ['/name/nm0905579/'],
#  'Jules Dassin': ['/name/nm0202088/'],
#  'Bert I. Gordon': ['/name/nm0330026/'],
#  'Nathan Juran': ['/name/nm0432846/'],
#  'Ray Kellogg': ['/name/nm0446129/'],
#  'Lewis Gilbert': ['/name/nm0318150/'],
#  'André De Toth': ['/name/nm0211964/'],
#  'Charles Jarrott': ['/name/nm0418986/'],
#  'Zoltan Korda': ['/name/nm0466113/'],
#  'Euzhan Palcy': ['/name/nm0657484/'],
#  'François Girard': ['/name/nm0320660/'],
#  'Herbert Ross': ['/name/nm0006889/'],
#  'Earl Bellamy': ['/name/nm0068691/'],
#  'Jack Conway': ['/name/nm0176699/'],
#  'David M. Rosenthal': ['/name/nm1270033/'],
#  'Isabel Coixet': ['/name/nm0170043/'],
#  'Paul Wendkos': ['/name/nm0920862/'],
#  'John Cromwell': ['/name/nm0188669/'],
#  'Brian Gilbert': ['/name/nm0317981/'],
#  'Ida Lupino': ['/name/nm0526946/'],
#  'Dylan Kidd': ['/name/nm1071898/'],
#  'Jay Martin': ['/name/nm2371848/'],
#  'Raoul Walsh': ['/name/nm0909825/'],
#  'Budd Boetticher': ['/name/nm0091430/'],
#  'Marleen Gorris': ['/name/nm0331296/'],
#  'Jeremiah S. Chechik': ['/name/nm0154819/'],
#  'Antonio Banderas': ['/name/nm0000104/'],
#  'Carlo Carlei': ['/name/nm0137363/'],
#  'Steve Buscemi': ['/name/nm0000114/'],
#  'Robert Montgomery': ['/name/nm0599910/'],
#  'Mark Griffiths': ['/name/nm0341716/'],
#  'Norman Z. McLeod': ['/name/nm0572851/'],
#  'Stanley Donen': ['/name/nm0002045/'],
#  'Phil Joanou': ['/name/nm0423333/'],
#  'Gene Saks': ['/name/nm0757256/'],
#  'Robert Harling': ['/name/nm0363326/'],
#  'Emily Young': ['/name/nm1369721/'],
#  'Dick Powell': ['/name/nm0694090/'],
#  'Clarence Brown': ['/name/nm0113284/'],
#  'Oliver Schmitz': ['/name/nm0005628/'],
#  'Anand Tucker': ['/name/nm0875793/'],
#  'Lindsay Anderson': ['/name/nm0000755/'],
#  'Edmund Goulding': ['/name/nm0332539/'],
#  'George Marshall': ['/name/nm0550892/'],
#  'David Miller': ['/name/nm0588183/'],
#  'James Dearden': ['/name/nm0213139/'],
#  'H.C. Potter': ['/name/nm0693281/'],
#  'Sandra Nettelbeck': ['/name/nm0626686/'],
#  'Malcolm Mowbray': ['/name/nm0610261/'],
#  'Dwight H. Little': ['/name/nm0514546/'],
#  'Mike Mills': ['/name/nm0590122/'],
#  'John Milius': ['/name/nm0587518/'],
#  'Erle C. Kenton': ['/name/nm0448915/'],
#  'Robert Towne': ['/name/nm0001801/'],
#  'Patrick Stettner': ['/name/nm0828099/'],
#  'Charles Barton': ['/name/nm0059106/'],
#  'Joseph Pevney': ['/name/nm0678928/'],
#  'Chuck Russell': ['/name/nm0751080/'],
#  'István Szabó': ['/name/nm0843640/'],
#  'Richard C. Sarafian': ['/name/nm0764781/'],
#  'Andrew van den Houten': ['/name/nm0886156/'],
#  'Peter Maris': ['/name/nm0548059/'],
#  'Christopher Cain': ['/name/nm0128883/'],
#  'William Richert': ['/name/nm0724927/'],
#  'Rawson Marshall Thurber': ['/name/nm1098493/'],
#  'Stephen Milburn Anderson': ['/name/nm0027465/'],
#  'Katja von Garnier': ['/name/nm0902290/'],
#  'Robert Siodmak': ['/name/nm0802563/'],
#  'Terence Davies': ['/name/nm0203993/'],
#  'John Byrum': ['/name/nm0126440/'],
#  'Brett Leonard': ['/name/nm0502577/'],
#  'Gordon Douglas': ['/name/nm0235066/'],
#  'Ivan Passer': ['/name/nm0664852/'],
#  'John Glenn': ['/name/nm1726457/'],
#  'Bob Dolman': ['/name/nm0231190/'],
#  'Stanley R. Jaffe': ['/name/nm0415494/'],
#  'Helen Hunt': ['/name/nm0000166/'],
#  'Chris Eyre': ['/name/nm0264220/'],
#  'Jeremiah Zagar': ['/name/nm1476102/'],
#  'Bill Forsyth': ['/name/nm0287025/'],
#  'Todd Phillips': ['/name/nm0680846/'],
#  'Fletcher Markle': ['/name/nm0548529/'],
#  'Alexander Mackendrick': ['/name/nm0533241/'],
#  'Jack Cardiff': ['/name/nm0002153/'],
#  'Philip Harder': ['/name/nm0362136/'],
#  'Roy Ward Baker': ['/name/nm0001928/'],
#  'Frank D. Gilroy': ['/name/nm0319663/'],
#  'Arthur Lubin': ['/name/nm0523893/'],
#  'Carl Schenkel': ['/name/nm0770918/'],
#  'Lajos Koltai': ['/name/nm0005759/'],
#  'Kevin Bacon': ['/name/nm0000102/'],
#  'Roger Corman': ['/name/nm0000339/'],
#  'Clare Kilner': ['/name/nm0453270/'],
#  'Terence Young': ['/name/nm0950109/'],
#  'Mel Ferrer': ['/name/nm0002072/'],
#  'Burt Lancaster': ['/name/nm0000044/'],
#  'Piers Haggard': ['/name/nm0353592/'],
#  'Gillies MacKinnon': ['/name/nm0533564/'],
#  'Tim Hunter': ['/name/nm0006853/'],
#  'Fred M. Wilcox': ['/name/nm0928208/'],
#  'John Polson': ['/name/nm0689852/'],
#  'Francis Megahy': ['/name/nm0576283/'],
#  'William Marshall': ['/name/nm0550777/'],
#  'Peter Kassovitz': ['/name/nm0440914/'],
#  'Jack Nicholson': ['/name/nm0000197/'],
#  'Carol Reed': ['/name/nm0715346/'],
#  'Larry Peerce': ['/name/nm0670282/'],
#  'Ben Bolt': ['/name/nm0093322/'],
#  'John Roberts': ['/name/nm0731253/'],
#  'Javier Elorrieta': ['/name/nm0255546/'],
#  'Josef von Sternberg': ['/name/nm0903049/'],
#  'Corey Allen': ['/name/nm0001904/'],
#  'David Gordon Green': ['/name/nm0337773/'],
#  'Franco Amurri': ['/name/nm0002171/'],
#  'Barry Shear': ['/name/nm0790395/'],
#  'Alan Roberts': ['/name/nm0003085/'],
#  'James Clavell': ['/name/nm0165412/'],
#  'Andrew Black': ['/name/nm10509441/'],
#  'Douglas Heyes': ['/name/nm0382227/'],
#  'Robert Clouse': ['/name/nm0167195/'],
#  'Larry Cohen': ['/name/nm0169540/'],
#  'Paul Bogart': ['/name/nm0091575/'],
#  'James Goldstone': ['/name/nm0326360/'],
#  'Martin Sheen': ['/name/nm0000640/'],
#  'Michael Corrente': ['/name/nm0180912/'],
#  'Jim Clark': ['/name/nm0164083/'],
#  'Peter Ho-Sun Chan': ['/name/nm0151066/'],
#  'Leslie Greif': ['/name/nm0340037/'],
#  'Rhys Ernst': ['/name/nm3636870/'],
#  'Bruce Beresford': ['/name/nm0000915/'],
#  'Hampton Fancher': ['/name/nm0266684/'],
#  'Willard Huyck': ['/name/nm0404754/'],
#  'Peter Medak': ['/name/nm0575389/'],
#  'Martha Coolidge': ['/name/nm0004838/'],
#  'Frank Tashlin': ['/name/nm0850895/'],
#  'Gary Entin': ['/name/nm1925528/'],
#  'Edward Bernds': ['/name/nm0076618/'],
#  'John Hoffman': ['/name/nm0388971/'],
#  'Norman Mailer': ['/name/nm0537551/'],
#  'William Beaudine': ['/name/nm0064415/'],
#  'Don Chaffey': ['/name/nm0149548/'],
#  'Michelle Manning': ['/name/nm0543339/'],
#  'Michael Buster': ['/name/nm2147659/'],
#  'Russell Mulcahy': ['/name/nm0611683/'],
#  'Pen Densham': ['/name/nm0219720/'],
#  'Luis Buñuel': ['/name/nm0000320/'],
#  'James B. Harris': ['/name/nm0364805/'],
#  'Walerian Borowczyk': ['/name/nm0097259/'],
#  'Robert M. Young': ['/name/nm0950001/'],
#  'Michael Almereyda': ['/name/nm0021899/'],
#  "Jim O'Connolly": ['/name/nm0640226/'],
#  'Chuck Jones': ['/name/nm0005062/'],
#  'Max Ophüls': ['/name/nm0649097/'],
#  'Compton Bennett': ['/name/nm0071682/'],
#  'Tia Brelis': ['/name/nm0107045/'],
#  'Jonathan Kahn': ['/name/nm4990509/'],
#  'Frank Borzage': ['/name/nm0097648/'],
#  'Paul Morrissey': ['/name/nm0607407/'],
#  'Hubert Cornfield': ['/name/nm0180369/'],
#  'Walter Grauman': ['/name/nm0336139/'],
#  'Cornel Wilde': ['/name/nm0664273/'],
#  'Yann Samuell': ['/name/nm1367933/'],
#  'Delbert Mann': ['/name/nm0542720/'],
#  'James Bolton': ['/name/nm0093404/'],
#  'John Flynn': ['/name/nm0283500/'],
#  'Allan Dwan': ['/name/nm0245385/'],
#  'Rowland V. Lee': ['/name/nm0498174/'],
#  'Griff Furst': ['/name/nm0975225/'],
#  'Jonas Åkerlund': ['/name/nm0959774/'],
#  'Chris Fisher': ['/name/nm1084723/'],
#  'Adam Simon': ['/name/nm0800048/'],
#  'John Malkovich': ['/name/nm0000518/'],
#  'Sidney Franklin': ['/name/nm0291548/'],
#  'Anatole Litvak': ['/name/nm0514822/'],
#  'Allen Reisner': ['/name/nm0718467/'],
#  'William F. Claxton': ['/name/nm0165493/'],
#  'Justin Lee': ['/name/nm4899218/'],
#  'Jan Egleson': ['/name/nm0251057/'],
#  'Kevin Billington': ['/name/nm0082543/'],
#  'Karl Freund': ['/name/nm0005713/'],
#  'Steve Carver': ['/name/nm0142587/'],
#  'David Greene': ['/name/nm0338719/'],
#  'Fred F. Sears': ['/name/nm0780764/'],
#  'Stephen Gyllenhaal': ['/name/nm0350455/'],
#  'Leif Tilden': ['/name/nm0863208/'],
#  'Edwin Sherin': ['/name/nm0792309/'],
#  'Ed Bianchi': ['/name/nm0080601/'],
#  'Philip Dunne': ['/name/nm0242897/'],
#  'Michael Bortman': ['/name/nm0097544/'],
#  'Alan Rudolph': ['/name/nm0748928/'],
#  'Mitchell Lichtenstein': ['/name/nm0509033/'],
#  'Trygve Allister Diesen': ['/name/nm0226148/'],
#  'David Price': ['/name/nm0002606/'],
#  'John Farrow': ['/name/nm0268513/'],
#  'Pinchas Perry': ['/name/nm0675257/'],
#  'Bernhard Wicki': ['/name/nm0926919/'],
#  'Bent Hamer': ['/name/nm0357584/'],
#  'Des McAnuff': ['/name/nm0005197/'],
#  'Lamont Johnson': ['/name/nm0425593/'],
#  'Arnold Laven': ['/name/nm0491852/'],
#  'Jean Renoir': ['/name/nm0719756/'],
#  'Jeremy Kagan': ['/name/nm0434571/'],
#  'William Girdler': ['/name/nm0320852/'],
#  'Daniel Petrie': ['/name/nm0677951/'],
#  'Ira Sachs': ['/name/nm0755158/'],
#  'Thomas Jane': ['/name/nm0005048/'],
#  'Dave Fleischer': ['/name/nm0281487/'],
#  'Richard A. Colla': ['/name/nm0171619/'],
#  'Will Mackenzie': ['/name/nm0533414/'],
#  'Mario Van Peebles': ['/name/nm0005522/'],
#  'David Twohy': ['/name/nm0878638/'],
#  'Curtis Bernhardt': ['/name/nm0076779/'],
#  'Peter Sasdy': ['/name/nm0765856/'],
#  "John 'Bud' Cardos": ['/name/nm0004616/'],
#  'Irvin Kershner': ['/name/nm0449984/'],
#  'Vincent McEveety': ['/name/nm0568546/'],
#  'Wesley Ruggles': ['/name/nm0749484/'],
#  'Franc Roddam': ['/name/nm0734466/'],
#  'Tommy Lee Wallace': ['/name/nm0908890/'],
#  'Richard Rich': ['/name/nm0723704/'],
#  'Irwin Winkler': ['/name/nm0005563/'],
#  'Will Finn': ['/name/nm0278181/'],
#  'Anthony Quinn': ['/name/nm0000063/'],
#  'Brian Jun': ['/name/nm0432420/'],
#  'Robert Collector': ['/name/nm0171720/'],
#  'Dan Ireland': ['/name/nm0006959/'],
#  'Menno Meyjes': ['/name/nm0583675/'],
#  'Daryl Duke': ['/name/nm0241174/'],
#  'David Berry': ['/name/nm2523512/'],
#  'Charles Vidor': ['/name/nm0896533/'],
#  'Phillip Borsos': ['/name/nm0097491/'],
#  ...}

# %%
director_link = movie_temp[['director','link_d']].set_index('director').T.to_dict('list')

# %%
director_link['Christopher Nolan'][0]
# Out:
# '/name/nm0634240/'
