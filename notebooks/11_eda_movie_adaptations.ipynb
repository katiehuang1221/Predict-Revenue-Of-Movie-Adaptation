# %%
"""
eda of 'movie_adaptations_data'

"""

# %% [markdown]
# ### Simple data visualization of movie adaptations data

# %%
import pandas as pd
import numpy as np

import pickle

import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn')

# %%
# Load 'movie_adaptations_data'
movie_df = pd.read_pickle('../dump/movie_adaptations_data')

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   movie_title          2000 non-null   object
#  1   rating               2000 non-null   float64
#  2   vote                 2000 non-null   int64
#  3   certificate          2000 non-null   object
#  4   genre                2000 non-null   object
#  5   release_date         2000 non-null   datetime64[ns]
#  6   metascore            614 non-null    float64
#  7   keywords             2000 non-null   object
#  8   budget               1393 non-null   float64
#  9   opening_weekend_usa  1178 non-null   float64
#  10  gross_usa            1354 non-null   float64
#  11  gross_world          1409 non-null   float64
#  12  runtime              1980 non-null   float64
#  13  distributor          1997 non-null   object
#  14  language             2000 non-null   object
#  15  country              2000 non-null   object
#  16  director             2000 non-null   object
#  17  writer               2000 non-null   object
#  18  star                 2000 non-null   object
#  19  link_d               2000 non-null   object
#  20  link_w               2000 non-null   object
#  21  link_s               2000 non-null   object
# dtypes: datetime64[ns](1), float64(7), int64(1), object(13)
# memory usage: 343.9+ KB

# %%
x = movie_df['release_date'].dt.year
y = movie_df['rating']
fig, ax = plt.subplots(1,1);
plt.scatter(x,y,alpha=0.5);
ax.set_title('',fontsize=15);
ax.set_xlabel('Year',fontsize=15);
ax.set_ylabel('Rating',fontsize=15);
ax.set_yticks([3,4,5,6,7,8,9]);
ax.set_yticklabels(['3.0','4.0','5.0','6.0','7.0','8.0','9.0']);
plt.xticks(fontsize=13);
plt.yticks(fontsize=13);

# %%
movie_df.dropna(subset=['gross_world'])
x = movie_df['gross_world']
y = movie_df['rating']
fig, ax = plt.subplots(1,1);
plt.scatter(x,y,alpha=0.5);
ax.set_title('',fontsize=15)
ax.set_xlabel('Gross World(USD)',fontsize=15);
ax.set_ylabel('Rating',fontsize=15)
ax.set_xticks([100e6,200e6,300e6,400e6])
ax.set_xticklabels(['100M','200M','300M','400M'])
ax.set_yticks([3,4,5,6,7,8,9])
ax.set_yticklabels(['3.0','4.0','5.0','6.0','7.0','8.0','9.0'])
plt.xticks(fontsize=13);
plt.yticks(fontsize=13);

# %%
movie_df.dropna(subset=['gross_usa'])
x = movie_df['gross_usa']
y = movie_df['rating']
fig, ax = plt.subplots(1,1)
plt.scatter(x,y,alpha=0.5)
ax.set_title('',fontsize=15)
ax.set_xlabel('Gross USA ($)',fontsize=15)
ax.set_ylabel('Rating',fontsize=15)
ax.set_xticks([100e6,200e6,300e6,400e6])
ax.set_xticklabels(['100M','200M','300M','400M'])
ax.set_yticks([3,4,5,6,7,8,9])
ax.set_yticklabels(['3.0','4.0','5.0','6.0','7.0','8.0','9.0'])
plt.xticks(fontsize=13);
plt.yticks(fontsize=13);

# %%
movie_df.dropna(subset=['vote'])
x = movie_df['vote']
y = movie_df['rating']

fig, ax = plt.subplots(1,1)
plt.scatter(x,y,alpha=0.5)
ax.set_title('',fontsize=15)
ax.set_xlabel('Vote (count)',fontsize=15)
ax.set_ylabel('Rating',fontsize=15)
ax.set_xticks([0,100e3,200e3,300e3,400e3,500e3,600e3,700e3,800e3])
ax.set_xticklabels(['0','100k','200k','300k','400k','500k','600k','700k','800k',])
ax.set_yticks([3,4,5,6,7,8,9])
ax.set_yticklabels(['3.0','4.0','5.0','6.0','7.0','8.0','9.0'])
plt.xticks(fontsize=13);
plt.yticks(fontsize=13);

# %%
movie_df.dropna(subset=['runtime'])
movie_df = movie_df[movie_df.runtime <300]
x = movie_df['runtime']
y = movie_df['rating']

fig, ax = plt.subplots(1,1)
plt.scatter(x,y,alpha=0.5)
ax.set_title('',fontsize=15)
ax.set_xlabel('Runtime (min)',fontsize=15)
ax.set_ylabel('Rating',fontsize=15)

ax.set_xticks([50,100,150,100,250])
ax.set_xticklabels(['50','100','150','200','250'])
ax.set_yticks([3,4,5,6,7,8,9])
ax.set_yticklabels(['3.0','4.0','5.0','6.0','7.0','8.0','9.0'])
plt.xticks(fontsize=13);
plt.yticks(fontsize=13);

# %%
# pairplot
sns.pairplot(movie_df)
