# %%
import pandas as pd
movie_df = pd.read_pickle('../dump/movie_data')

# %%
movie_df
# Out:
#                                             movie_title  rating     vote  \
# 0                                     After We Collided     5.0    16193
# 1                                         The Godfather     9.2  1613156
# 2                 Harry Potter and the Sorcerer's Stone     7.6   654081
# 3                                               Unknown     6.8   248401
# 4     The Lord of the Rings: The Fellowship of the Ring     8.8  1655208
# ...                                                 ...     ...      ...
# 1995                                    V.I. Warshawski     5.0     4710
# 1996                               Anne of Green Gables     7.0     1113
# 1997                              Odds Against Tomorrow     7.4     3780
# 1998                                 Once Is Not Enough     4.6      629
# 1999                        Unidentified Flying Oddball     5.3      992
#
#      certificate                         genre release_date  metascore  \
# ...
